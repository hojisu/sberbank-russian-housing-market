# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1. Train Data
# - Data Types
# - categorical column
# - Distribution price / log_price
# - Change of House Price Over Time
# - Correlation between Train Data Features
# - Missing Data
# - Relationship between Independent Variable and Price
# - categorical feature
#
# ## 2. Macro Data
# - macro data type
# - categorical column
# - Correlation between Features
# - missing data
#
# ## 3. Train vs Test data
# - Comparison between Distributions of Train and Test Data

# %%
pd.options.display.max_columns = 300

# %matplotlib inline

# %% [markdown]
# # 1. Train data

# %%
# Train data
df_train = pd.read_csv('./data/train.csv', parse_dates=['timestamp'])
df_train.tail(10)
# Out:
#           id  timestamp  full_sq  life_sq  floor  max_floor  material  \
# 30461  30464 2015-06-30       36     19.0    5.0       16.0       1.0
# 30462  30465 2015-06-30       47     30.0   23.0       25.0       4.0
# 30463  30466 2015-06-30       56     29.0   13.0       14.0       1.0
# 30464  30467 2015-06-30       56     51.0   19.0       19.0       1.0
# 30465  30468 2015-06-30       52      NaN   13.0       17.0       1.0
# 30466  30469 2015-06-30       44     27.0    7.0        9.0       1.0
# 30467  30470 2015-06-30       86     59.0    3.0        9.0       2.0
# 30468  30471 2015-06-30       45      NaN   10.0       20.0       1.0
# 30469  30472 2015-06-30       64     32.0    5.0       15.0       1.0
# 30470  30473 2015-06-30       43     28.0    1.0        9.0       1.0
#
#        build_year  num_room  kitch_sq  state   product_type  \
# 30461      1980.0       1.0       8.0    3.0     Investment
# 30462      2016.0       1.0      10.0    1.0  OwnerOccupier
# 30463      2001.0       2.0      11.0    3.0     Investment
# 30464      2017.0       2.0       1.0    1.0  OwnerOccupier
# 30465         NaN       2.0       1.0    1.0  OwnerOccupier
# 30466      1975.0       2.0       6.0    3.0     Investment
# 30467      1935.0       4.0      10.0    3.0     Investment
# 30468         NaN       1.0       1.0    1.0  OwnerOccupier
# 30469      2003.0       2.0      11.0    2.0     Investment
# 30470      1968.0       2.0       6.0    2.0     Investment
#
#                    sub_area        area_m  raion_popul  green_zone_part  \
# 30461          Obruchevskoe  6.050065e+06        78616         0.167526
# 30462        Filevskij Park  9.629358e+06        89467         0.343754
# 30463      Severnoe Tushino  9.249237e+06       156377         0.374068
# 30464              Sviblovo  4.441296e+06        60315         0.137976
# 30465              Tverskoe  7.307411e+06        75377         0.065444
# 30466              Otradnoe  1.005305e+07       175518         0.096270
# 30467              Tverskoe  7.307411e+06        75377         0.065444
# 30468  Poselenie Vnukovskoe  2.553630e+07         4001         0.496315
# 30469          Obruchevskoe  6.050065e+06        78616         0.167526
# 30470           Novogireevo  4.395333e+06        94561         0.063755
#
#        indust_part  children_preschool  preschool_quota  \
# 30461     0.093443                4215           2372.0
# 30462     0.238617                3903           1522.0
# 30463     0.000000               10190           4116.0
# 30464     0.178917                3694           2057.0
# 30465     0.000078                4237           1874.0
# 30466     0.300323                9753           5088.0
# 30467     0.000078                4237           1874.0
# 30468     0.007122                 275              NaN
# 30469     0.093443                4215           2372.0
# 30470     0.038693                6120           2215.0
#
#        preschool_education_centers_raion  children_school  school_quota  \
# 30461                                  6             4635        6083.0
# 30462                                  5             3889        4904.0
# 30463                                  5            11319        9891.0
# 30464                                  1             3594        3741.0
# 30465                                  4             6398        6772.0
# 30466                                  4            10311       12721.0
# 30467                                  4             6398        6772.0
# 30468                                  0              264           NaN
# 30469                                  6             4635        6083.0
# 30470                                  4             6533        5824.0
#
#        school_education_centers_raion  school_education_centers_top_20_raion  \
# 30461                               8                                      0
# 30462                               5                                      0
# 30463                               5                                      0
# 30464                               2                                      0
# 30465                               4                                      1
# 30466                               4                                      0
# 30467                               4                                      1
# 30468                               0                                      0
# 30469                               8                                      0
# 30470                               4                                      0
#
#        hospital_beds_raion  healthcare_centers_raion  university_top_20_raion  \
# 30461               3300.0                         2                        1
# 30462                705.0                         3                        0
# 30463               1145.0                         3                        0
# 30464                192.0                         1                        0
# 30465               1046.0                         3                        2
# 30466                  NaN                         1                        0
# 30467               1046.0                         3                        2
# 30468                  NaN                         0                        0
# 30469               3300.0                         2                        1
# 30470               1015.0                         2                        0
#
#        sport_objects_raion  additional_education_raion culture_objects_top_25  \
# 30461                   11                           1                     no
# 30462                   18                           1                     no
# 30463                    1                           2                     no
# 30464                    4                           6                     no
# 30465                   29                          16                    yes
# 30466                   10                           3                     no
# 30467                   29                          16                    yes
# 30468                    0                           0                     no
# 30469                   11                           1                     no
# 30470                    7                           1                     no
#
#        culture_objects_top_25_raion  shopping_centers_raion  office_raion  \
# 30461                             0                       4             5
# 30462                             0                       6             6
# 30463                             0                       5             0
# 30464                             0                       5             4
# 30465                            10                      23           141
# 30466                             0                       9             6
# 30467                            10                      23           141
# 30468                             0                       1             0
# 30469                             0                       4             5
# 30470                             0                       5             1
#
#       thermal_power_plant_raion incineration_raion oil_chemistry_raion  \
# 30461                        no                 no                  no
# 30462                        no                 no                  no
# 30463                        no                 no                  no
# 30464                        no                 no                  no
# 30465                        no                 no                  no
# 30466                        no                yes                  no
# 30467                        no                 no                  no
# 30468                        no                 no                  no
# 30469                        no                 no                  no
# 30470                        no                 no                  no
#
#       radiation_raion railroad_terminal_raion big_market_raion  \
# 30461             yes                      no               no
# 30462             yes                      no               no
# 30463              no                      no               no
# 30464              no                      no               no
# 30465             yes                     yes               no
# 30466             yes                      no               no
# 30467             yes                     yes               no
# 30468              no                      no               no
# 30469             yes                      no               no
# 30470             yes                      no               no
#
#       nuclear_reactor_raion detention_facility_raion  full_all  male_f  \
# 30461                    no                       no     83844   36656
# 30462                    no                       no    112804   51631
# 30463                    no                       no     53786   24231
# 30464                    no                       no     37502   17105
# 30465                    no                      yes    116742   52836
# 30466                    no                       no     61396   27916
# 30467                    no                      yes    116742   52836
# 30468                    no                       no     17790    8350
# 30469                    no                       no     83844   36656
# 30470                    no                       no     72131   34296
#
#        female_f  young_all  young_male  young_female  work_all  work_male  \
# 30461     47188       9414        4815          4599     51445      25003
# 30462     61173       8294        4236          4058     65115      38782
# 30463     29555      22961       12039         10922     93843      47269
# 30464     20397       7706        3714          3992     40289      20014
# 30465     63906      11272        5470          5802     43921      21901
# 30466     33480      21400       11094         10306    112133      59089
# 30467     63906      11272        5470          5802     43921      21901
# 30468      9443        574         297           277      2566       1356
# 30469     47188       9414        4815          4599     51445      25003
# 30470     37835      13523        6724          6799     56908      27219
#
#        work_female  ekder_all  ekder_male  ekder_female  0_6_all  0_6_male  \
# 30461        26442      17757        5579         12178     4215      2161
# 30462        26333      16058        4692         11366     3903      1989
# 30463        46574      39573       12538         27035    10190      5334
# 30464        20275      12320        3460          8860     3694      1821
# 30465        22020      20184        6644         13540     4237      2079
# 30466        53044      41985       12703         29282     9753      5044
# 30467        22020      20184        6644         13540     4237      2079
# 30468         1211        861         244           617      275       143
# 30469        26442      17757        5579         12178     4215      2161
# 30470        29689      24130        7105         17025     6120      3096
#
#        0_6_female  7_14_all  7_14_male  7_14_female  0_17_all  0_17_male  \
# 30461        2054      4635       2364         2271     10896       5572
# 30462        1914      3889       1971         1918      9249       4691
# 30463        4856     11319       5929         5390     26095      13597
# 30464        1873      3594       1679         1915      8741       4311
# 30465        2158      6398       3094         3304     12508       6065
# 30466        4709     10311       5335         4976     23849      12412
# 30467        2158      6398       3094         3304     12508       6065
# 30468         133       264        136          128       646        336
# 30469        2054      4635       2364         2271     10896       5572
# 30470        3024      6533       3192         3341     14994       7422
#
#        0_17_female  16_29_all  16_29_male  16_29_female  0_13_all  0_13_male  \
# 30461         5324      15835        7398          8437      8301       4219
# 30462         4558      23768       11420         12348      7332       3715
# 30463        12498      11372        5629          5743     20140      10531
# 30464         4430       7290        3575          3715      6859       3295
# 30465         6443      23480       11491         11989      9955       4835
# 30466        11437      11588        5359          6229     18732       9663
# 30467         6443      23480       11491         11989      9955       4835
# 30468          311       3796        2035          1762       506        261
# 30469         5324      15835        7398          8437      8301       4219
# 30470         7572      17070        7717          9353     11903       5928
#
#        0_13_female  raion_build_count_with_material_info  build_count_block  \
# 30461         4082                                 185.0               38.0
# 30462         3617                                 295.0               26.0
# 30463         9609                                 318.0               50.0
# 30464         3564                                 180.0               58.0
# 30465         5120                                 651.0               19.0
# 30466         9069                                 282.0               35.0
# 30467         5120                                 651.0               19.0
# 30468          245                                   NaN                NaN
# 30469         4082                                 185.0               38.0
# 30470         5975                                 304.0              108.0
#
#        build_count_wood  build_count_frame  build_count_brick  \
# 30461               0.0                0.0                4.0
# 30462              16.0                7.0              170.0
# 30463               7.0                1.0               16.0
# 30464               0.0                0.0               61.0
# 30465              27.0                4.0              529.0
# 30466               0.0                0.0               20.0
# 30467              27.0                4.0              529.0
# 30468               NaN                NaN                NaN
# 30469               0.0                0.0                4.0
# 30470               2.0                0.0              105.0
#
#        build_count_monolith  build_count_panel  build_count_foam  \
# 30461                   9.0              134.0               0.0
# 30462                   7.0               61.0               0.0
# 30463                   9.0              235.0               0.0
# 30464                   0.0               60.0               0.0
# 30465                  25.0               41.0               0.0
# 30466                   5.0              222.0               0.0
# 30467                  25.0               41.0               0.0
# 30468                   NaN                NaN               NaN
# 30469                   9.0              134.0               0.0
# 30470                   4.0               85.0               0.0
#
#        build_count_slag  build_count_mix  \
# 30461               0.0              0.0
# 30462               7.0              1.0
# 30463               0.0              0.0
# 30464               1.0              0.0
# 30465               5.0              1.0
# 30466               0.0              0.0
# 30467               5.0              1.0
# 30468               NaN              NaN
# 30469               0.0              0.0
# 30470               0.0              0.0
#
#        raion_build_count_with_builddate_info  build_count_before_1920  \
# 30461                                  186.0                      0.0
# 30462                                  295.0                      1.0
# 30463                                  318.0                      0.0
# 30464                                  177.0                      0.0
# 30465                                  650.0                    263.0
# 30466                                  282.0                      0.0
# 30467                                  650.0                    263.0
# 30468                                    NaN                      NaN
# 30469                                  186.0                      0.0
# 30470                                  303.0                      1.0
#
#        build_count_1921-1945  build_count_1946-1970  build_count_1971-1995  \
# 30461                    0.0                   84.0                   36.0
# 30462                   10.0                  179.0                   67.0
# 30463                    2.0                  165.0                   93.0
# 30464                    0.0                  123.0                   30.0
# 30465                  105.0                  154.0                   71.0
# 30466                    0.0                   14.0                  246.0
# 30467                  105.0                  154.0                   71.0
# 30468                    NaN                    NaN                    NaN
# 30469                    0.0                   84.0                   36.0
# 30470                    2.0                  220.0                   66.0
#
#        build_count_after_1995  ID_metro  metro_min_avto  metro_km_avto  \
# 30461                    66.0        68        3.000099       1.596772
# 30462                    38.0        67        3.380114       2.117112
# 30463                    58.0        22        2.622565       1.580238
# 30464                    24.0       189        0.815305       0.652244
# 30465                    57.0       120        1.482746       1.036568
# 30466                    22.0        24        1.384021       0.659002
# 30467                    57.0       187        1.060577       0.781217
# 30468                     NaN        21        2.152792       1.722233
# 30469                    66.0        65        3.377814       2.047312
# 30470                    14.0        49        0.584636       0.454650
#
#        metro_min_walk  metro_km_walk  kindergarten_km  school_km   park_km  \
# 30461       17.619417       1.468285         0.417062   0.249355  1.198874
# 30462       25.004226       2.083685         0.726512   1.071225  1.717844
# 30463        8.510351       0.709196         0.225720   0.193474  1.876243
# 30464        7.447930       0.620661         0.414927   0.566309  0.680210
# 30465       13.459068       1.121589         1.048962   0.269716  0.284300
# 30466        8.158093       0.679841         0.132645   0.349899  1.972527
# 30467        9.374609       0.781217         0.276256   0.362681  1.036452
# 30468       20.666800       1.722233         0.897889   1.234235  4.566595
# 30469       24.567748       2.047312         0.203020   0.130667  1.772506
# 30470        5.455795       0.454650         0.093619   0.378950  0.848766
#
#        green_zone_km  industrial_km  water_treatment_km  cemetery_km  \
# 30461       0.364467       1.240444            9.872418     4.448785
# 30462       0.395254       0.000000           14.695410     2.479746
# 30463       0.349807       1.646417           16.656070     3.837756
# 30464       0.143626       0.000000           20.271190     0.675383
# 30465       0.189089       2.640803           10.378040     4.242627
# 30466       0.139814       0.702853           22.746320     1.933090
# 30467       0.271861       0.473020           13.867820     1.336968
# 30468       0.427248       0.353642           16.784630     2.250137
# 30469       0.227547       2.397723           11.397520     3.216746
# 30470       0.559699       0.455194           10.451010     1.791075
#
#        incineration_km  railroad_station_walk_km  railroad_station_walk_min  \
# 30461        10.253950                  6.497470                  77.969644
# 30462        12.494230                  2.869833                  34.437993
# 30463         9.035385                  5.303922                  63.647059
# 30464         3.855104                  3.262078                  39.144932
# 30465        12.180740                  3.378717                  40.544603
# 30466         1.870053                  3.147161                  37.765933
# 30467         8.928301                  0.902227                  10.826720
# 30468        19.149190                  3.735666                  44.827989
# 30469         9.815678                  6.895862                  82.750340
# 30470         8.334879                  2.037754                  24.453053
#
#        ID_railroad_station_walk  railroad_station_avto_km  \
# 30461                      33.0                  6.717998
# 30462                      14.0                  2.953295
# 30463                       4.0                  5.642933
# 30464                      78.0                  2.021472
# 30465                       5.0                  4.060430
# 30466                       1.0                  3.217988
# 30467                      83.0                  1.726532
# 30468                      24.0                  3.735666
# 30469                      33.0                  8.059414
# 30470                      31.0                  2.037754
#
#        railroad_station_avto_min  ID_railroad_station_avto  \
# 30461                   8.954612                        33
# 30462                   5.843856                        14
# 30463                   7.553860                        41
# 30464                   4.475919                        95
# 30465                   5.143798                        32
# 30466                   5.300256                         1
# 30467                   2.242220                        83
# 30468                   4.782323                        24
# 30469                   9.128624                       105
# 30470                   3.604917                        31
#
#        public_transport_station_km  public_transport_station_min_walk  \
# 30461                     0.079129                           0.949552
# 30462                     0.264910                           3.178926
# 30463                     0.189581                           2.274970
# 30464                     0.086493                           1.037921
# 30465                     0.326035                           3.912418
# 30466                     0.093258                           1.119101
# 30467                     0.090712                           1.088544
# 30468                     0.630014                           7.560163
# 30469                     0.261528                           3.138330
# 30470                     0.250151                           3.001814
#
#        water_km water_1line    mkad_km     ttk_km  sadovoe_km  bulvar_ring_km  \
# 30461  0.450691          no   5.109462   5.886573    8.641846        9.765618
# 30462  0.420686          no   8.705758   1.412825    4.625218        5.574358
# 30463  0.684074          no   1.486707  11.896884   14.587359       15.339712
# 30464  0.241299          no   5.363124   6.173473    8.405744        9.080098
# 30465  0.524839          no  13.917815   4.081283    2.185333        0.506919
# 30466  0.979218          no   3.762408   8.361875   10.543724       11.118577
# 30467  1.063533          no  13.100989   1.238732    1.203215        1.874868
# 30468  0.394422          no   7.123215  17.148737   19.868997       21.038561
# 30469  0.738539          no   2.327138   8.940313   11.752036       12.872535
# 30470  0.518509          no   1.920884   6.809408    9.675169       10.228634
#
#        kremlin_km  big_road1_km  ID_big_road1 big_road1_1line  big_road2_km  \
# 30461   10.516156      0.189926            16              no      4.866214
# 30462    6.514713      1.412825             4              no      1.599896
# 30463   16.626186      1.486707             1              no      1.814075
# 30464   10.514468      1.908253            20              no      2.420685
# 30465    0.072897      4.081283             4              no      4.273395
# 30466   12.599292      3.096057             5              no      3.762408
# 30467    3.269284      1.238732             4              no      1.245704
# 30468   21.905792      2.808077            13              no      3.688405
# 30469   13.622569      0.960608            16              no      2.174001
# 30470   11.812614      1.920884             1              no      2.089230
#
#        ID_big_road2  railroad_km railroad_1line  zd_vokzaly_avto_km  \
# 30461            51     4.392597             no           11.086655
# 30462            32     0.042636            yes            7.586885
# 30463            54     2.233835             no           16.154691
# 30464            15     0.356344             no            7.185917
# 30465            34     2.566044             no            4.060430
# 30466             1     1.137603             no           11.396447
# 30467            34     0.377368             no            1.010437
# 30468            27     1.727223             no           25.699461
# 30469            51     4.898047             no           15.303338
# 30470            10     0.734949             no           12.243439
#
#        ID_railroad_terminal  bus_terminal_avto_km  ID_bus_terminal  \
# 30461                    32              9.324360                8
# 30462                    50              9.660969                5
# 30463                    83              7.303186                1
# 30464                   101             10.672440                4
# 30465                    32              3.983721               13
# 30466                   101             15.454302                4
# 30467                    83              4.173555                5
# 30468                    50             17.366661                8
# 30469                    32              5.458660                8
# 30470                     5              5.645123                3
#
#        oil_chemistry_km  nuclear_reactor_km  radiation_km  \
# 30461         17.657161            5.024888      0.980352
# 30462         15.726400            5.063289      0.740870
# 30463         23.873753            6.342002      2.538578
# 30464         13.150104            6.461345      3.071397
# 30465          8.750185            6.663317      0.890001
# 30466         15.994941            4.993393      2.371148
# 30467         10.988510            7.537125      1.711271
# 30468         29.968660           17.397666      9.036942
# 30469         19.591574            8.011139      0.718679
# 30470          3.261652           14.359141      0.999365
#
#        power_transmission_line_km  thermal_power_plant_km     ts_km  \
# 30461                    1.570339                5.321350  5.179705
# 30462                    0.480153                3.071726  1.377786
# 30463                    1.973502                5.721404  0.434827
# 30464                    0.487546                7.957548  1.434000
# 30465                    5.444976                4.308531  3.757130
# 30466                    2.046756                6.668360  1.833401
# 30467                    3.295494                5.408912  3.215552
# 30468                    5.506770               10.102328  3.729416
# 30469                    1.971656                6.417997  3.781523
# 30470                    1.832979                5.239948  1.415294
#
#        big_market_km  market_shop_km  fitness_km  swim_pool_km  ice_rink_km  \
# 30461       6.381658        2.638460    0.229101      2.259806     6.496373
# 30462      18.654048        5.429086    0.634820      1.374012     3.728174
# 30463      20.481457        0.293278    1.003262      3.155594     7.261430
# 30464       7.475368        2.929117    0.378930      2.893346     2.057277
# 30465       7.836658        1.092897    0.269716      1.421099     0.501856
# 30466       8.820934        0.812253    0.063432      2.190217     0.720736
# 30467      12.102735        1.825643    0.398831      1.133905     2.896280
# 30468      15.546028        6.433794    1.519553      2.521691     2.715850
# 30469       2.515959        2.711199    0.412813      0.631280     2.630674
# 30470      14.028112        1.902431    0.819001      2.370789     1.684764
#
#        stadium_km  basketball_km  hospice_morgue_km  detention_facility_km  \
# 30461    2.798207       1.814491           1.560281              14.544518
# 30462    1.415487       2.307619           2.052117               4.113151
# 30463    5.830524       1.790333           2.046936              11.415882
# 30464    4.650307       2.866780           0.972930               5.152820
# 30465    4.018205       1.171506           0.615658               3.939382
# 30466    6.769773       3.470281           3.817988               4.589571
# 30467    2.965732       1.912873           0.951754               0.416625
# 30468   13.898607       8.355285           7.401423              25.084813
# 30469    2.374106       2.210500           1.625064              24.788893
# 30470    3.641656       0.812511           0.633901               8.868202
#
#        public_healthcare_km  university_km  workplaces_km  \
# 30461              1.556684       2.824177       3.501005
# 30462              0.981008       1.223753       2.271688
# 30463              0.849823       9.445872       2.106114
# 30464              2.238348       1.895763       1.766675
# 30465              2.608162       2.180440       1.091507
# 30466              1.786763       2.236806       1.442576
# 30467              1.663019       0.672662       0.796851
# 30468              2.052908      12.893684       9.479093
# 30469              2.328096       1.982450       2.340429
# 30470              0.964828       2.731394       3.065101
#
#        shopping_centers_km  office_km  additional_education_km  preschool_km  \
# 30461             0.195491   0.276479                 0.141536      0.249355
# 30462             0.146429   0.146429                 0.858923      1.071225
# 30463             0.232778   1.491458                 0.648281      0.193474
# 30464             0.187828   0.969990                 0.510751      0.566309
# 30465             0.107360   0.182194                 0.000000      0.269716
# 30466             0.325885   1.103579                 0.167718      0.349899
# 30467             0.540003   0.069986                 0.086552      0.362681
# 30468             1.806570   4.338453                 1.339078      1.234235
# 30469             1.108672   1.204798                 1.340017      0.130667
# 30470             0.224601   2.108265                 0.825811      0.378950
#
#        big_church_km  church_synagogue_km  mosque_km  theater_km  museum_km  \
# 30461       1.198874             1.200435   0.700070    3.326351   3.457176
# 30462       0.635582             0.477586   3.379879    2.795791   2.003606
# 30463       0.283044             2.040548  10.098335   23.720332  12.198090
# 30464       1.261711             0.532268   2.867605    3.672399   2.988268
# 30465       0.181897             0.184681   1.827838    2.370385   0.695251
# 30466       1.235066             0.612359   1.558875    7.482165   4.836787
# 30467       0.850385             0.310021   2.226056    0.778428   1.450108
# 30468       1.192543             1.186621  12.652956   13.459593   9.890758
# 30469       1.644053             0.476021   2.748055    2.088193   4.119706
# 30470       0.480531             0.867332   8.987913    0.688707   0.127867
#
#        exhibition_km  catering_km       ecology  green_part_500  \
# 30461       2.717175     0.189304  satisfactory            8.58
# 30462       3.878493     0.380884  satisfactory            3.47
# 30463       1.486290     0.090138  satisfactory            2.63
# 30464       2.024731     0.658499          poor           12.38
# 30465       1.184340     0.107759     excellent           12.24
# 30466       4.877876     0.055377          good            3.38
# 30467       3.543784     0.007476          poor            5.64
# 30468       4.555385     0.066503       no data            3.33
# 30469       1.800186     0.134566  satisfactory           14.85
# 30470       2.477068     0.182831          poor            0.00
#
#        prom_part_500  office_count_500  office_sqm_500  trc_count_500  \
# 30461           0.00                 1           11500              2
# 30462          56.84                 1            4000              1
# 30463           0.00                 0               0              1
# 30464          11.67                 0               0              1
# 30465           0.00                10          131844              6
# 30466           0.00                 0               0              2
# 30467           0.80                14          392972              0
# 30468           3.70                 0               0              0
# 30469           0.00                 0               0              0
# 30470           1.26                 0               0              3
#
#        trc_sqm_500  cafe_count_500  cafe_sum_500_min_price_avg  \
# 30461         7600               5                      860.00
# 30462         4000               2                      400.00
# 30463        50380               2                      400.00
# 30464       238000               0                         NaN
# 30465       467600              71                      954.84
# 30466        41970               8                      614.29
# 30467            0              34                      777.42
# 30468            0               2                     1000.00
# 30469            0               3                     1000.00
# 30470         6906               4                      400.00
#
#        cafe_sum_500_max_price_avg  cafe_avg_price_500  \
# 30461                     1400.00             1130.00
# 30462                      750.00              575.00
# 30463                      750.00              575.00
# 30464                         NaN                 NaN
# 30465                     1564.52             1259.68
# 30466                     1071.43              842.86
# 30467                     1322.58             1050.00
# 30468                     1750.00             1375.00
# 30469                     1500.00             1250.00
# 30470                      750.00              575.00
#
#        cafe_count_500_na_price  cafe_count_500_price_500  \
# 30461                        0                         1
# 30462                        0                         1
# 30463                        0                         1
# 30464                        0                         0
# 30465                        9                        19
# 30466                        1                         1
# 30467                        3                         7
# 30468                        0                         0
# 30469                        0                         0
# 30470                        0                         2
#
#        cafe_count_500_price_1000  cafe_count_500_price_1500  \
# 30461                          1                          2
# 30462                          1                          0
# 30463                          1                          0
# 30464                          0                          0
# 30465                         11                         13
# 30466                          4                          2
# 30467                         11                          6
# 30468                          1                          0
# 30469                          0                          3
# 30470                          2                          0
#
#        cafe_count_500_price_2500  cafe_count_500_price_4000  \
# 30461                          1                          0
# 30462                          0                          0
# 30463                          0                          0
# 30464                          0                          0
# 30465                         14                          4
# 30466                          0                          0
# 30467                          7                          0
# 30468                          1                          0
# 30469                          0                          0
# 30470                          0                          0
#
#        cafe_count_500_price_high  big_church_count_500  church_count_500  \
# 30461                          0                     0                 0
# 30462                          0                     0                 1
# 30463                          0                     1                 0
# 30464                          0                     0                 0
# 30465                          1                     8                15
# 30466                          0                     0                 0
# 30467                          0                     0                 1
# 30468                          0                     0                 0
# 30469                          0                     0                 1
# 30470                          0                     1                 0
#
#        mosque_count_500  leisure_count_500  sport_count_500  market_count_500  \
# 30461                 0                  0                3                 0
# 30462                 0                  0                0                 0
# 30463                 0                  0                0                 1
# 30464                 0                  0                2                 0
# 30465                 0                  0                9                 1
# 30466                 0                  0                1                 0
# 30467                 0                  1                1                 0
# 30468                 0                  0                0                 0
# 30469                 0                  0                3                 0
# 30470                 0                  4                0                 0
#
#        green_part_1000  prom_part_1000  office_count_1000  office_sqm_1000  \
# 30461            11.61            0.00                  3            62474
# 30462             9.99           40.87                  1             4000
# 30463            18.88            0.00                  0                0
# 30464            29.90            6.36                  1             7020
# 30465             7.51            0.00                 47           649057
# 30466            10.51            7.72                  0                0
# 30467             1.84           11.58                 56          1143488
# 30468            36.66            2.92                  0                0
# 30469            23.65            0.00                  0                0
# 30470             3.46            5.41                  0                0
#
#        trc_count_1000  trc_sqm_1000  cafe_count_1000  \
# 30461               2          7600               18
# 30462               1          4000                3
# 30463               2         50380                3
# 30464               2        239276                6
# 30465              20        842476              316
# 30466               3         79970               20
# 30467               5         89090              160
# 30468               0             0                2
# 30469               0             0               13
# 30470               4         25106               11
#
#        cafe_sum_1000_min_price_avg  cafe_sum_1000_max_price_avg  \
# 30461                       872.22                      1444.44
# 30462                       766.67                      1333.33
# 30463                       400.00                       750.00
# 30464                       716.67                      1166.67
# 30465                       914.53                      1500.00
# 30466                       666.67                      1138.89
# 30467                       699.35                      1183.01
# 30468                      1000.00                      1750.00
# 30469                       753.85                      1269.23
# 30470                       581.82                      1045.45
#
#        cafe_avg_price_1000  cafe_count_1000_na_price  \
# 30461              1158.33                         0
# 30462              1050.00                         0
# 30463               575.00                         1
# 30464               941.67                         0
# 30465              1207.26                        20
# 30466               902.78                         2
# 30467               941.18                         7
# 30468              1375.00                         0
# 30469              1011.54                         0
# 30470               813.64                         0
#
#        cafe_count_1000_price_500  cafe_count_1000_price_1000  \
# 30461                          4                           4
# 30462                          1                           1
# 30463                          1                           1
# 30464                          1                           2
# 30465                         94                          56
# 30466                          5                           7
# 30467                         50                          51
# 30468                          0                           1
# 30469                          1                           6
# 30470                          3                           6
#
#        cafe_count_1000_price_1500  cafe_count_1000_price_2500  \
# 30461                           5                           5
# 30462                           0                           1
# 30463                           0                           0
# 30464                           3                           0
# 30465                          68                          50
# 30466                           4                           2
# 30467                          30                          20
# 30468                           0                           1
# 30469                           5                           1
# 30470                           1                           1
#
#        cafe_count_1000_price_4000  cafe_count_1000_price_high  \
# 30461                           0                           0
# 30462                           0                           0
# 30463                           0                           0
# 30464                           0                           0
# 30465                          27                           1
# 30466                           0                           0
# 30467                           1                           1
# 30468                           0                           0
# 30469                           0                           0
# 30470                           0                           0
#
#        big_church_count_1000  church_count_1000  mosque_count_1000  \
# 30461                      0                  0                  1
# 30462                      1                  1                  0
# 30463                      1                  0                  0
# 30464                      0                  2                  0
# 30465                     16                 35                  0
# 30466                      0                  1                  0
# 30467                      2                  8                  0
# 30468                      0                  0                  0
# 30469                      0                  5                  0
# 30470                      2                  1                  0
#
#        leisure_count_1000  sport_count_1000  market_count_1000  \
# 30461                   0                 3                  0
# 30462                   0                 5                  0
# 30463                   0                 0                  1
# 30464                   0                 2                  0
# 30465                  11                16                  1
# 30466                   0                 3                  1
# 30467                   1                 8                  0
# 30468                   0                 0                  0
# 30469                   0                10                  0
# 30470                   4                 3                  0
#
#        green_part_1500  prom_part_1500  office_count_1500  office_sqm_1500  \
# 30461            13.36            4.36                  9           193414
# 30462            11.05           43.52                  5            29700
# 30463            35.92            0.00                  1             9881
# 30464            23.33           11.64                  5            71043
# 30465             5.70            0.00                120          1259653
# 30466             8.81           10.02                  5           217042
# 30467             2.55            8.69                105          1815698
# 30468            43.85            1.55                  0                0
# 30469            32.98            0.00                  1            37800
# 30470            19.95            2.41                  0                0
#
#        trc_count_1500  trc_sqm_1500  cafe_count_1500  \
# 30461               5         52100               53
# 30462               5        182141               13
# 30463               3         55380               12
# 30464               3        257491               13
# 30465              25       1075476              643
# 30466               6        109230               28
# 30467               7        121090              292
# 30468               0             0                3
# 30469               1         28800               42
# 30470               5         39106               17
#
#        cafe_sum_1500_min_price_avg  cafe_sum_1500_max_price_avg  \
# 30461                       796.23                      1301.89
# 30462                       575.00                      1041.67
# 30463                       733.33                      1222.22
# 30464                       784.62                      1307.69
# 30465                       899.17                      1476.03
# 30466                       646.15                      1115.38
# 30467                       762.18                      1269.09
# 30468                       833.33                      1500.00
# 30469                       646.34                      1097.56
# 30470                       600.00                      1058.82
#
#        cafe_avg_price_1500  cafe_count_1500_na_price  \
# 30461              1049.06                         0
# 30462               808.33                         1
# 30463               977.78                         3
# 30464              1046.15                         0
# 30465              1187.60                        38
# 30466               880.77                         2
# 30467              1015.64                        17
# 30468              1166.67                         0
# 30469               871.95                         1
# 30470               829.41                         0
#
# ...
#
#        cafe_count_2000_price_1500  cafe_count_2000_price_2500  \
# 30461                          23                           9
# 30462                          11                           7
# 30463                           5                           1
# 30464                           4                           3
# 30465                         257                         150
# 30466                           7                           2
# 30467                         100                          58
# 30468                           2                           1
# 30469                          15                           9
# 30470                           4                           1
#
#        cafe_count_2000_price_4000  cafe_count_2000_price_high  \
# 30461                           1                           1
# 30462                           1                           1
# 30463                           0                           0
# 30464                           0                           0
# 30465                          63                          10
# 30466                           1                           0
# 30467                          13                           4
# 30468                           0                           0
# 30469                           0                           0
# 30470                           0                           0
#
#        big_church_count_2000  church_count_2000  mosque_count_2000  \
# 30461                      1                  4                  1
# 30462                      1                  2                  0
# 30463                      1                  0                  0
# 30464                      3                  6                  0
# 30465                     67                104                  1
# 30466                      2                  5                  1
# 30467                      9                 28                  0
# 30468                      1                  2                  0
# 30469                      1                 12                  0
# 30470                      2                  3                  0
#
#        leisure_count_2000  sport_count_2000  market_count_2000  \
# 30461                   0                22                  1
# 30462                   1                16                  0
# 30463                   1                 5                  1
# 30464                   0                16                  1
# 30465                  47                42                  2
# 30466                   0                15                  3
# 30467                  17                36                  2
# 30468                   0                 3                  0
# 30469                   2                18                  2
# 30470                   5                12                  2
#
#        green_part_3000  prom_part_3000  office_count_3000  office_sqm_3000  \
# 30461            11.93            6.61                 33           965517
# 30462            13.66           22.41                 52          3207952
# 30463            25.72            5.74                  6            85311
# 30464            23.88           15.35                 14           249219
# 30465             6.96            0.99                486          5082992
# 30466            13.14           21.25                 17           410183
# 30467             6.52           11.35                299          4208928
# 30468            41.64            2.11                  0                0
# 30469            30.31            1.47                 15           473168
# 30470            28.52            3.87                  6           155237
#
#        trc_count_3000  trc_sqm_3000  cafe_count_3000  \
# 30461              23        619795              202
# 30462              16       1101867              157
# 30463              14        408398               48
# 30464              18        945536               87
# 30465              54       1702619             1815
# 30466              22        745130               79
# 30467              28        845372             1039
# 30468               2         22000                9
# 30469              25        481350              115
# 30470              13        545023               47
#
#        cafe_sum_3000_min_price_avg  cafe_sum_3000_max_price_avg  \
# 30461                       711.86                      1198.45
# 30462                       931.94                      1548.61
# 30463                       609.30                      1046.51
# 30464                       669.51                      1128.05
# 30465                       882.31                      1453.00
# 30466                       647.89                      1112.68
# 30467                       895.84                      1476.65
# 30468                       700.00                      1222.22
# 30469                       681.48                      1152.78
# 30470                       595.65                      1054.35
#
#        cafe_avg_price_3000  cafe_count_3000_na_price  \
# 30461               955.15                         8
# 30462              1240.28                        13
# 30463               827.91                         5
# 30464               898.78                         5
# 30465              1167.66                       113
# 30466               880.28                         8
# 30467              1186.24                        54
# 30468               961.11                         0
# 30469               917.13                         7
# 30470               825.00                         1
#
#        cafe_count_3000_price_500  cafe_count_3000_price_1000  \
# 30461                         47                          73
# 30462                         34                          39
# 30463                         14                          17
# 30464                         28                          26
# 30465                        449                         432
# 30466                         20                          30
# 30467                        268                         258
# 30468                          1                           5
# 30469                         32                          37
# 30470                         13                          24
#
#        cafe_count_3000_price_1500  cafe_count_3000_price_2500  \
# 30461                          54                          18
# 30462                          29                          31
# 30463                           9                           3
# 30464                          19                           8
# 30465                         446                         255
# 30466                          15                           5
# 30467                         230                         155
# 30468                           2                           1
# 30469                          26                          13
# 30470                           6                           2
#
#        cafe_count_3000_price_4000  cafe_count_3000_price_high  \
# 30461                           1                           1
# 30462                          10                           1
# 30463                           0                           0
# 30464                           1                           0
# 30465                         105                          15
# 30466                           1                           0
# 30467                          57                          17
# 30468                           0                           0
# 30469                           0                           0
# 30470                           1                           0
#
#        big_church_count_3000  church_count_3000  mosque_count_3000  \
# 30461                      1                 13                  1
# 30462                      3                  9                  0
# 30463                      6                  3                  0
# 30464                      6                 13                  1
# 30465                     94                162                  2
# 30466                      5                 12                  1
# 30467                     35                 62                  1
# 30468                      1                  4                  0
# 30469                      2                 17                  1
# 30470                      3                  7                  0
#
#        leisure_count_3000  sport_count_3000  market_count_3000  \
# 30461                   4                50                  2
# 30462                   4                36                  2
# 30463                   1                12                  1
# 30464                   3                32                  3
# 30465                  85                88                  6
# 30466                   0                29                  3
# 30467                  48                80                  4
# 30468                   0                 6                  0
# 30469                   2                33                  4
# 30470                   7                26                  4
#
#        green_part_5000  prom_part_5000  office_count_5000  office_sqm_5000  \
# 30461            23.36            3.48                 53          1444054
# 30462            15.64           11.84                169          4967675
# 30463            18.94            7.97                 25           712296
# 30464            24.12           15.18                 53           929992
# 30465             6.80            5.73                774          9997846
# 30466            15.52           17.24                 44           838601
# 30467             8.29           12.85                617          9949843
# 30468            35.62            6.96                  1           117300
# 30469            30.36            9.33                 39          1225712
# 30470            25.10           10.16                 15           351244
#
#        trc_count_5000  trc_sqm_5000  cafe_count_5000  \
# 30461              47       1145385              359
# 30462              40       2276854              606
# 30463              41        867953              150
# 30464              35       1313276              226
# 30465             101       3346565             2625
# 30466              53       2548292              207
# 30467              90       4345915             2197
# 30468               4        201300               20
# 30469              45       1464521              230
# 30470              22        646575               93
#
#        cafe_sum_5000_min_price_avg  cafe_sum_5000_max_price_avg  \
# 30461                       756.10                      1264.53
# 30462                      1039.68                      1699.29
# 30463                       709.93                      1195.04
# 30464                       680.29                      1153.85
# 30465                       880.53                      1451.32
# 30466                       689.95                      1156.08
# 30467                       887.43                      1462.88
# 30468                       747.37                      1263.16
# 30469                       703.20                      1182.65
# 30470                       664.44                      1127.78
#
#        cafe_avg_price_5000  cafe_count_5000_na_price  \
# 30461              1010.32                        15
# 30462              1369.48                        44
# 30463               952.48                         9
# 30464               917.07                        18
# 30465              1165.93                       170
# 30466               923.02                        18
# 30467              1175.16                       136
# 30468              1005.26                         1
# 30469               942.92                        11
# 30470               896.11                         3
#
#        cafe_count_5000_price_500  cafe_count_5000_price_1000  \
# 30461                         77                         119
# 30462                        116                         135
# 30463                         37                          50
# 30464                         70                          69
# 30465                        639                         642
# 30466                         63                          59
# 30467                        550                         535
# 30468                          4                           8
# 30469                         60                          77
# 30470                         26                          35
#
#        cafe_count_5000_price_1500  cafe_count_5000_price_2500  \
# 30461                         102                          41
# 30462                         143                          99
# 30463                          38                          14
# 30464                          41                          25
# 30465                         636                         371
# 30466                          47                          15
# 30467                         511                         313
# 30468                           5                           1
# 30469                          58                          22
# 30470                          22                           5
#
#        cafe_count_5000_price_4000  cafe_count_5000_price_high  \
# 30461                           4                           1
# 30462                          57                          12
# 30463                           2                           0
# 30464                           3                           0
# 30465                         141                          26
# 30466                           5                           0
# 30467                         128                          24
# 30468                           1                           0
# 30469                           1                           1
# 30470                           2                           0
#
#        big_church_count_5000  church_count_5000  mosque_count_5000  \
# 30461                      4                 35                  1
# 30462                     23                 42                  1
# 30463                     13                 12                  0
# 30464                     14                 29                  1
# 30465                    150                249                  2
# 30466                     15                 26                  1
# 30467                     98                182                  1
# 30468                      2                 12                  0
# 30469                      6                 31                  1
# 30470                      7                 16                  0
#
#        leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 30461                   6                80                  6    5000000
# 30462                  13               123                  7   10544070
# 30463                   1                53                  6   12000000
# 30464                   4                90                  6   10262010
# 30465                 105               203                 13    6750554
# 30466                   2                84                  6    7400000
# 30467                  82               171                 15   25000000
# 30468                   1                11                  1    6970959
# 30469                   4                65                  7   13500000
# 30470                   9                54                 10    5600000

# %%
df_train.shape
# Out:
# (30471, 292)

# %% [markdown]
# # Data Types

# %%
df_dtype = df_train.dtypes.reset_index()
df_dtype.columns = ['Count', 'Column Type']
df_dtype.groupby('Column Type').aggregate('count').reset_index()
# Out:
#       Column Type  Count
# 0           int64    157
# 1  datetime64[ns]      1
# 2         float64    119
# 3          object     15

# %% [markdown]
# ## categorical column
# - "procuct_type"
#     - Investment, OwnerOccupier
# - "sub_area" column has 146 different sub-area names.
# - Features have yes/no value
#     - culture_objects_top_25
#     - thermal_power_plant_raion
#     - incineration_raion
#     - oil_chemistry_raion
#     - radiation_raion
#     - railroad_terminal_raion
#     - big_market_raion
#     - nuclear_reactor_raion
#     - detention_facility_raion
#     - water_1line
#     - big_road1_1line
#     - railroad_1line
# - "ecology"
#     - good, excellent, poor, satisfactory, no data

# %% [markdown]
# # Distribution price / log_price

# %%
# price histogram -> right skewed 
def price_histogram():
    fig,ax = plt.subplots(1,2, figsize=(20,8))
    ax1,ax2 = ax.flatten()

    df_train.price_doc.plot.hist(bins=20, color='Purple', edgecolor='black', ax=ax1);
    ax1.set_title('Price Histograms', fontsize=17)
    ax1.set_ylabel('')
    ax1.set_xlabel('')

    log_price = np.log(df_train.price_doc)
    sns.distplot(log_price,  bins=30, color='tomato', kde=True, ax=ax2)
    ax2.set_title("Price Distribution Histogram", fontsize=17)
    ax2.set_ylabel("")
    ax2.set_xlabel('')
    plt.subplots_adjust(wspace=0.2);

price_histogram()

# %% [markdown]
# # Change of House Price Over Time

# %%
df_train['yearmonth'] = df_train['timestamp'].map(lambda x: str(x)[:4] + str(x)[5:7])
grouped_df = df_train.groupby('yearmonth')['price_doc'].aggregate(np.mean).reset_index()
plt.figure(figsize=(12, 8))
plt.ylabel('Median Price', fontsize=12)
plt.xlabel('Year Month', fontsize=12)
plt.xticks(rotation='vertical')
sns.barplot(grouped_df.yearmonth.values, grouped_df.price_doc.values, color='r')
plt.show()
df_train = df_train[df_train.columns.drop('yearmonth')]

# %% [markdown]
# # Correlation between Train Data Features

# %%
# df_train = df_train.select_dtypes(include=['int64', 'float64'])

corr = df_train.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False 

plt.figure(figsize=(17, 17))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Missing Data

# %%
df_missing = df_train.isnull().sum(axis=0).reset_index()
df_missing.columns = ['column_name', 'missing_count']
df_missing = df_missing.loc[df_missing['missing_count']>0]
ind = np.arange(df_missing.shape[0])
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(ind, (df_missing.missing_count.values/len(df_train))*100, color='r')
ax.set_yticks(ind)
ax.set_yticklabels(df_missing.column_name.values, rotation='horizontal')
ax.set_xlabel("% of missing values")
plt.show()

# %% [markdown]
# # Relationship between Independent Variable and Price

# %%
corrs = sorted([(df_train['price_doc'].corr(df_train[f]), f) for f in df_train._get_numeric_data().columns.drop('price_doc')], reverse=True)[:10]
features = [f[1] for f in corrs]

for f in features:
    fig  = plt.figure(figsize=(9, 3), dpi=100)
    fig.suptitle("{}'s distribution and regression with price_doc".format(f))

    axes1 = fig.add_subplot(121)
    axes2 = fig.add_subplot(122) 
    sns.distplot(df_train[f].dropna(), ax=axes1)
    sns.regplot(x=f, y='price_doc', data=df_train[[f, 'price_doc']], ax=axes2, scatter_kws={"s": 10, "color":"b"}, line_kws={"color":"r"})
    fig.tight_layout()
    plt.show()

# %% [markdown]
# # categorical feature

# %%
fig  = plt.figure(figsize=(5, 13), dpi=100)
axes1 = fig.add_subplot(311)
axes2 = fig.add_subplot(312)
sns.violinplot(df_train['product_type'], np.log(df_train['price_doc']), ax=axes1)
sns.violinplot(df_train['ecology'], np.log(df_train['price_doc']), ax=axes2)

# %% [markdown]
# # 2. macro data

# %%
df_macro = pd.read_csv('./data/macro.csv', parse_dates=['timestamp'])
df_macro.tail(10)
# Out:
#       timestamp  oil_urals  gdp_quart  gdp_quart_growth    cpi    ppi  \
# 2474 2016-10-10    44.3677    19979.4              -0.6  531.0  601.9
# 2475 2016-10-11    44.3677    19979.4              -0.6  531.0  601.9
# 2476 2016-10-12    44.3677    19979.4              -0.6  531.0  601.9
# 2477 2016-10-13    44.3677    19979.4              -0.6  531.0  601.9
# 2478 2016-10-14    44.3677    19979.4              -0.6  531.0  601.9
# 2479 2016-10-15    44.3677    19979.4              -0.6  531.0  601.9
# 2480 2016-10-16    44.3677    19979.4              -0.6  531.0  601.9
# 2481 2016-10-17    44.3677    19979.4              -0.6  531.0  601.9
# 2482 2016-10-18    44.3677    19979.4              -0.6  531.0  601.9
# 2483 2016-10-19    44.3677    19979.4              -0.6  531.0  601.9
#
#       gdp_deflator  balance_trade  balance_trade_growth   usdrub   eurrub  \
# 2474        133.16          5.823                   2.6  62.0086  69.0988
# 2475        133.16          5.823                   2.6  62.6543  69.3498
# 2476        133.16          5.823                   2.6  62.9110  69.3887
# 2477        133.16          5.823                   2.6  62.9178  69.4544
# 2478        133.16          5.823                   2.6  62.9573  69.0250
# 2479        133.16          5.823                   2.6  62.9573  69.0250
# 2480        133.16          5.823                   2.6  62.9573  69.0250
# 2481        133.16          5.823                   2.6  63.0856  69.3953
# 2482        133.16          5.823                   2.6  62.9512  69.1790
# 2483        133.16          5.823                   2.6  62.9512  69.1790
#
#       brent  net_capital_export  gdp_annual  gdp_annual_growth  \
# 2474  53.14           -0.408111     80804.3          -0.037267
# 2475  52.41           -0.408111     80804.3          -0.037267
# 2476  51.81           -0.408111     80804.3          -0.037267
# 2477  52.03           -0.408111     80804.3          -0.037267
# 2478  51.95           -0.408111     80804.3          -0.037267
# 2479  51.95           -0.408111     80804.3          -0.037267
# 2480  51.95           -0.408111     80804.3          -0.037267
# 2481  51.52           -0.408111     80804.3          -0.037267
# 2482  51.68           -0.408111     80804.3          -0.037267
# 2483  51.68           -0.408111     80804.3          -0.037267
#
#       average_provision_of_build_contract  \
# 2474                                  6.2
# 2475                                  6.2
# 2476                                  6.2
# 2477                                  6.2
# 2478                                  6.2
# 2479                                  6.2
# 2480                                  6.2
# 2481                                  6.2
# 2482                                  6.2
# 2483                                  6.2
#
#       average_provision_of_build_contract_moscow      rts    micex  \
# 2474                                        7.71  1017.88  2001.10
# 2475                                        7.71  1005.48  2001.42
# 2476                                        7.71   995.96  1993.35
# 2477                                        7.71   987.99  1976.37
# 2478                                        7.71   983.04  1966.39
# 2479                                        7.71   983.04  1966.39
# 2480                                        7.71   983.04  1966.39
# 2481                                        7.71   977.30  1956.95
# 2482                                        7.71   986.94  1969.11
# 2483                                        7.71   990.65  1966.45
#
#       micex_rgbi_tr  micex_cbi_tr  deposits_value  deposits_growth  \
# 2474         134.01        313.73        23453188         0.016931
# 2475         133.84        313.73        23453188         0.016931
# 2476         133.70        313.73        23453188         0.016931
# 2477         133.37        314.18        23453188         0.016931
# 2478         133.55        313.73        23453188         0.016931
# 2479         133.55        313.73        23453188         0.016931
# 2480         133.55        313.73        23453188         0.016931
# 2481         133.09        313.61        23453188         0.016931
# 2482         132.88        313.21        23453188         0.016931
# 2483         133.15        313.21        23453188         0.016931
#
#       deposits_rate  mortgage_value  mortgage_growth  mortgage_rate  grp  \
# 2474            NaN          899539         0.382095          12.66  NaN
# 2475            NaN          899539         0.382095          12.66  NaN
# 2476            NaN          899539         0.382095          12.66  NaN
# 2477            NaN          899539         0.382095          12.66  NaN
# 2478            NaN          899539         0.382095          12.66  NaN
# 2479            NaN          899539         0.382095          12.66  NaN
# 2480            NaN          899539         0.382095          12.66  NaN
# 2481            NaN          899539         0.382095          12.66  NaN
# 2482            NaN          899539         0.382095          12.66  NaN
# 2483            NaN          899539         0.382095          12.66  NaN
#
#       grp_growth  income_per_cap  real_dispos_income_per_cap_growth  salary  \
# 2474         NaN             NaN                                NaN     NaN
# 2475         NaN             NaN                                NaN     NaN
# 2476         NaN             NaN                                NaN     NaN
# 2477         NaN             NaN                                NaN     NaN
# 2478         NaN             NaN                                NaN     NaN
# 2479         NaN             NaN                                NaN     NaN
# 2480         NaN             NaN                                NaN     NaN
# 2481         NaN             NaN                                NaN     NaN
# 2482         NaN             NaN                                NaN     NaN
# 2483         NaN             NaN                                NaN     NaN
#
#       salary_growth  fixed_basket  retail_trade_turnover  \
# 2474            NaN      20354.78                    NaN
# 2475            NaN      20354.78                    NaN
# 2476            NaN      20354.78                    NaN
# 2477            NaN      20354.78                    NaN
# 2478            NaN      20354.78                    NaN
# 2479            NaN      20354.78                    NaN
# 2480            NaN      20354.78                    NaN
# 2481            NaN      20354.78                    NaN
# 2482            NaN      20354.78                    NaN
# 2483            NaN      20354.78                    NaN
#
#       retail_trade_turnover_per_cap  retail_trade_turnover_growth  \
# 2474                            NaN                           NaN
# 2475                            NaN                           NaN
# 2476                            NaN                           NaN
# 2477                            NaN                           NaN
# 2478                            NaN                           NaN
# 2479                            NaN                           NaN
# 2480                            NaN                           NaN
# 2481                            NaN                           NaN
# 2482                            NaN                           NaN
# 2483                            NaN                           NaN
#
#       labor_force  unemployment  employment  invest_fixed_capital_per_cap  \
# 2474          NaN           NaN         NaN                           NaN
# 2475          NaN           NaN         NaN                           NaN
# 2476          NaN           NaN         NaN                           NaN
# 2477          NaN           NaN         NaN                           NaN
# 2478          NaN           NaN         NaN                           NaN
# 2479          NaN           NaN         NaN                           NaN
# 2480          NaN           NaN         NaN                           NaN
# 2481          NaN           NaN         NaN                           NaN
# 2482          NaN           NaN         NaN                           NaN
# 2483          NaN           NaN         NaN                           NaN
#
#       invest_fixed_assets  profitable_enterpr_share  \
# 2474                  NaN                       NaN
# 2475                  NaN                       NaN
# 2476                  NaN                       NaN
# 2477                  NaN                       NaN
# 2478                  NaN                       NaN
# 2479                  NaN                       NaN
# 2480                  NaN                       NaN
# 2481                  NaN                       NaN
# 2482                  NaN                       NaN
# 2483                  NaN                       NaN
#
#       unprofitable_enterpr_share  share_own_revenues  overdue_wages_per_cap  \
# 2474                         NaN                 NaN                    NaN
# 2475                         NaN                 NaN                    NaN
# 2476                         NaN                 NaN                    NaN
# 2477                         NaN                 NaN                    NaN
# 2478                         NaN                 NaN                    NaN
# 2479                         NaN                 NaN                    NaN
# 2480                         NaN                 NaN                    NaN
# 2481                         NaN                 NaN                    NaN
# 2482                         NaN                 NaN                    NaN
# 2483                         NaN                 NaN                    NaN
#
#       fin_res_per_cap  marriages_per_1000_cap  divorce_rate  \
# 2474              NaN                     NaN           NaN
# 2475              NaN                     NaN           NaN
# 2476              NaN                     NaN           NaN
# 2477              NaN                     NaN           NaN
# 2478              NaN                     NaN           NaN
# 2479              NaN                     NaN           NaN
# 2480              NaN                     NaN           NaN
# 2481              NaN                     NaN           NaN
# 2482              NaN                     NaN           NaN
# 2483              NaN                     NaN           NaN
#
#       construction_value  invest_fixed_assets_phys  pop_natural_increase  \
# 2474                 NaN                       NaN                   NaN
# 2475                 NaN                       NaN                   NaN
# 2476                 NaN                       NaN                   NaN
# 2477                 NaN                       NaN                   NaN
# 2478                 NaN                       NaN                   NaN
# 2479                 NaN                       NaN                   NaN
# 2480                 NaN                       NaN                   NaN
# 2481                 NaN                       NaN                   NaN
# 2482                 NaN                       NaN                   NaN
# 2483                 NaN                       NaN                   NaN
#
#       pop_migration  pop_total_inc  childbirth  mortality  housing_fund_sqm  \
# 2474            NaN            NaN         NaN        NaN               NaN
# 2475            NaN            NaN         NaN        NaN               NaN
# 2476            NaN            NaN         NaN        NaN               NaN
# 2477            NaN            NaN         NaN        NaN               NaN
# 2478            NaN            NaN         NaN        NaN               NaN
# 2479            NaN            NaN         NaN        NaN               NaN
# 2480            NaN            NaN         NaN        NaN               NaN
# 2481            NaN            NaN         NaN        NaN               NaN
# 2482            NaN            NaN         NaN        NaN               NaN
# 2483            NaN            NaN         NaN        NaN               NaN
#
#       lodging_sqm_per_cap  water_pipes_share  baths_share  sewerage_share  \
# 2474                  NaN                NaN          NaN             NaN
# 2475                  NaN                NaN          NaN             NaN
# 2476                  NaN                NaN          NaN             NaN
# 2477                  NaN                NaN          NaN             NaN
# 2478                  NaN                NaN          NaN             NaN
# 2479                  NaN                NaN          NaN             NaN
# 2480                  NaN                NaN          NaN             NaN
# 2481                  NaN                NaN          NaN             NaN
# 2482                  NaN                NaN          NaN             NaN
# 2483                  NaN                NaN          NaN             NaN
#
#       gas_share  hot_water_share  electric_stove_share  heating_share  \
# 2474        NaN              NaN                   NaN            NaN
# 2475        NaN              NaN                   NaN            NaN
# 2476        NaN              NaN                   NaN            NaN
# 2477        NaN              NaN                   NaN            NaN
# 2478        NaN              NaN                   NaN            NaN
# 2479        NaN              NaN                   NaN            NaN
# 2480        NaN              NaN                   NaN            NaN
# 2481        NaN              NaN                   NaN            NaN
# 2482        NaN              NaN                   NaN            NaN
# 2483        NaN              NaN                   NaN            NaN
#
#       old_house_share  average_life_exp  infant_mortarity_per_1000_cap  \
# 2474              NaN               NaN                            NaN
# 2475              NaN               NaN                            NaN
# 2476              NaN               NaN                            NaN
# 2477              NaN               NaN                            NaN
# 2478              NaN               NaN                            NaN
# 2479              NaN               NaN                            NaN
# 2480              NaN               NaN                            NaN
# 2481              NaN               NaN                            NaN
# 2482              NaN               NaN                            NaN
# 2483              NaN               NaN                            NaN
#
#       perinatal_mort_per_1000_cap  incidence_population  \
# 2474                          NaN                   NaN
# 2475                          NaN                   NaN
# 2476                          NaN                   NaN
# 2477                          NaN                   NaN
# 2478                          NaN                   NaN
# 2479                          NaN                   NaN
# 2480                          NaN                   NaN
# 2481                          NaN                   NaN
# 2482                          NaN                   NaN
# 2483                          NaN                   NaN
#
#       rent_price_4+room_bus  rent_price_3room_bus  rent_price_2room_bus  \
# 2474                 180.76                 99.65                 69.81
# 2475                 180.76                 99.65                 69.81
# 2476                 180.76                 99.65                 69.81
# 2477                 180.76                 99.65                 69.81
# 2478                 180.76                 99.65                 69.81
# 2479                 180.76                 99.65                 69.81
# 2480                 180.76                 99.65                 69.81
# 2481                 180.76                 99.65                 69.81
# 2482                 180.76                 99.65                 69.81
# 2483                 180.76                 99.65                 69.81
#
#       rent_price_1room_bus  rent_price_3room_eco  rent_price_2room_eco  \
# 2474                  50.2                 45.71                  38.4
# 2475                  50.2                 45.71                  38.4
# 2476                  50.2                 45.71                  38.4
# 2477                  50.2                 45.71                  38.4
# 2478                  50.2                 45.71                  38.4
# 2479                  50.2                 45.71                  38.4
# 2480                  50.2                 45.71                  38.4
# 2481                  50.2                 45.71                  38.4
# 2482                  50.2                 45.71                  38.4
# 2483                  50.2                 45.71                  38.4
#
#       rent_price_1room_eco  load_of_teachers_preschool_per_teacher  \
# 2474                 29.78                                     NaN
# 2475                 29.78                                     NaN
# 2476                 29.78                                     NaN
# 2477                 29.78                                     NaN
# 2478                 29.78                                     NaN
# 2479                 29.78                                     NaN
# 2480                 29.78                                     NaN
# 2481                 29.78                                     NaN
# 2482                 29.78                                     NaN
# 2483                 29.78                                     NaN
#
#      child_on_acc_pre_school  load_of_teachers_school_per_teacher  \
# 2474                     NaN                                  NaN
# 2475                     NaN                                  NaN
# 2476                     NaN                                  NaN
# 2477                     NaN                                  NaN
# 2478                     NaN                                  NaN
# 2479                     NaN                                  NaN
# 2480                     NaN                                  NaN
# 2481                     NaN                                  NaN
# 2482                     NaN                                  NaN
# 2483                     NaN                                  NaN
#
#       students_state_oneshift modern_education_share  \
# 2474                      NaN                    NaN
# 2475                      NaN                    NaN
# 2476                      NaN                    NaN
# 2477                      NaN                    NaN
# 2478                      NaN                    NaN
# 2479                      NaN                    NaN
# 2480                      NaN                    NaN
# 2481                      NaN                    NaN
# 2482                      NaN                    NaN
# 2483                      NaN                    NaN
#
#      old_education_build_share  provision_doctors  provision_nurse  \
# 2474                       NaN                NaN              NaN
# 2475                       NaN                NaN              NaN
# 2476                       NaN                NaN              NaN
# 2477                       NaN                NaN              NaN
# 2478                       NaN                NaN              NaN
# 2479                       NaN                NaN              NaN
# 2480                       NaN                NaN              NaN
# 2481                       NaN                NaN              NaN
# 2482                       NaN                NaN              NaN
# 2483                       NaN                NaN              NaN
#
#       load_on_doctors  power_clinics  hospital_beds_available_per_cap  \
# 2474              NaN            NaN                              NaN
# 2475              NaN            NaN                              NaN
# 2476              NaN            NaN                              NaN
# 2477              NaN            NaN                              NaN
# 2478              NaN            NaN                              NaN
# 2479              NaN            NaN                              NaN
# 2480              NaN            NaN                              NaN
# 2481              NaN            NaN                              NaN
# 2482              NaN            NaN                              NaN
# 2483              NaN            NaN                              NaN
#
#       hospital_bed_occupancy_per_year  provision_retail_space_sqm  \
# 2474                              NaN                         NaN
# 2475                              NaN                         NaN
# 2476                              NaN                         NaN
# 2477                              NaN                         NaN
# 2478                              NaN                         NaN
# 2479                              NaN                         NaN
# 2480                              NaN                         NaN
# 2481                              NaN                         NaN
# 2482                              NaN                         NaN
# 2483                              NaN                         NaN
#
#       provision_retail_space_modern_sqm  turnover_catering_per_cap  \
# 2474                                NaN                        NaN
# 2475                                NaN                        NaN
# 2476                                NaN                        NaN
# 2477                                NaN                        NaN
# 2478                                NaN                        NaN
# 2479                                NaN                        NaN
# 2480                                NaN                        NaN
# 2481                                NaN                        NaN
# 2482                                NaN                        NaN
# 2483                                NaN                        NaN
#
#       theaters_viewers_per_1000_cap  seats_theather_rfmin_per_100000_cap  \
# 2474                            NaN                                  NaN
# 2475                            NaN                                  NaN
# 2476                            NaN                                  NaN
# 2477                            NaN                                  NaN
# 2478                            NaN                                  NaN
# 2479                            NaN                                  NaN
# 2480                            NaN                                  NaN
# 2481                            NaN                                  NaN
# 2482                            NaN                                  NaN
# 2483                            NaN                                  NaN
#
#       museum_visitis_per_100_cap  bandwidth_sports  \
# 2474                         NaN               NaN
# 2475                         NaN               NaN
# 2476                         NaN               NaN
# 2477                         NaN               NaN
# 2478                         NaN               NaN
# 2479                         NaN               NaN
# 2480                         NaN               NaN
# 2481                         NaN               NaN
# 2482                         NaN               NaN
# 2483                         NaN               NaN
#
#       population_reg_sports_share  students_reg_sports_share  apartment_build  \
# 2474                          NaN                        NaN              NaN
# 2475                          NaN                        NaN              NaN
# 2476                          NaN                        NaN              NaN
# 2477                          NaN                        NaN              NaN
# 2478                          NaN                        NaN              NaN
# 2479                          NaN                        NaN              NaN
# 2480                          NaN                        NaN              NaN
# 2481                          NaN                        NaN              NaN
# 2482                          NaN                        NaN              NaN
# 2483                          NaN                        NaN              NaN
#
#       apartment_fund_sqm
# 2474                 NaN
# 2475                 NaN
# 2476                 NaN
# 2477                 NaN
# 2478                 NaN
# 2479                 NaN
# 2480                 NaN
# 2481                 NaN
# 2482                 NaN
# 2483                 NaN

# %% [markdown]
# ## macro data type

# %%
df_macro.shape
# Out:
# (2484, 100)

# %%
df_dtype = df_macro.dtypes.reset_index()
df_dtype.columns = ['Count', 'Column Type']
df_dtype.groupby('Column Type').aggregate('count').reset_index()
# Out:
#       Column Type  Count
# 0  datetime64[ns]      1
# 1           int64      2
# 2         float64     94
# 3          object      3

# %%
df_macro.select_dtypes(include=['object']).tail(5)
# Out:
#      child_on_acc_pre_school modern_education_share old_education_build_share
# 2479                     NaN                    NaN                       NaN
# 2480                     NaN                    NaN                       NaN
# 2481                     NaN                    NaN                       NaN
# 2482                     NaN                    NaN                       NaN
# 2483                     NaN                    NaN                       NaN

# %% [markdown]
# # categorical column
# - child_on_acc_pre_school
#     - '45,713', '#!', '7,311', '3,013', '16,765', nan
# - "modern_education_share"
#     - nan, '90,92', '93,08', '95,4918'
# - old_education_build_share
#     - nan, '23,14', '25,47', '8,2517'

# %% [markdown]
# # Correlation between Features

# %%
corr = df_macro.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False 

plt.figure(figsize=(17, 17))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # missing data

# %%
df_missing = df_macro.isnull().sum(axis=0).reset_index()
df_missing.columns = ['column_name', 'missing_count']
df_missing = df_missing.loc[df_missing['missing_count']>0]
ind = np.arange(df_missing.shape[0])
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(ind, (df_missing.missing_count.values/len(df_train))*100, color='r')
ax.set_yticks(ind)
ax.set_yticklabels(df_missing.column_name.values, rotation='horizontal')
ax.set_xlabel("% of missing values")
plt.show()

# %% [markdown]
# # 3. Train vs Test data
# - Comparison between Distributions of Train and Test Data

# %%
df_test = pd.read_csv('./data/test.csv', parse_dates=['timestamp'])

# %%
corrs = sorted([(df_train['price_doc'].corr(df_train[f]), f) for f in df_train._get_numeric_data().columns.drop('price_doc')], reverse=True)[:10]
features = [f[1] for f in corrs]

# %% [markdown]
# # Comparison between Distributions of Train and Test Data

# %%
for f in features:
    fig = plt.figure(figsize=(8, 4), dpi=100)
    axes1 = fig.add_subplot(121)
    sns.distplot(df_train[f].dropna(), ax=axes1, color="r")
    axes2 = fig.add_subplot(122)
    sns.distplot(df_test[f].dropna(), ax=axes2, color="r")
    axes1.set_title("Train")
    axes2.set_title("Test")

# %%
for cf in ['ecology', 'material', 'product_type']:
    fig = plt.figure(figsize=(14, 4), dpi=100)
    
    axes1 = fig.add_subplot(121)
    sns.countplot(df_train[cf].dropna(), ax=axes1, palette="vlag")

    axes2 = fig.add_subplot(122)
    sns.countplot(df_test[cf].dropna(), ax=axes2, palette="vlag")

    axes1.set_title("Train")
    axes2.set_title("Test")

# %% [markdown]
# This shows that the distributions of train and test data are similar.
