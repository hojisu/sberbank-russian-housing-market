# %% [markdown]
# # Modeling with StatsModels

# %% [markdown]
# ## 1. Ordinary Least Square
# - Column Names
# - Log Transformation
# - Condition Number
# - Standard Scaling

# %% [markdown]
# # 2. Dimensionality Reduction
# - ANOVA
# - F-test and Feature Influence

# %% [markdown]
# # 3. Outlier
# - Cook's Distance

# %% [markdown]
# # 4. Regularization
# - Lasso

# %% [markdown]
# # 5. Diagnosis of Regression
# - Residual Normality Test
# - Partial Regression Plot

# %% [markdown]
# # 6. Cross Validatoin

# %% [markdown]
# # 7. Test
# - score

# %%
# %matplotlib inline
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
import warnings
import sys
import datetime
import scipy as sp
import statsmodels.stats.api as sms
import statsmodels.api as sm
from patsy import dmatrix
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
import utils.statsmodel_helper as sh
import utils.feature_selection as fs
import utils.preprocessing as pp
import utils.error_calculator as ec

class SMWrapper(BaseEstimator, RegressorMixin):
    """ A universal sklearn-style wrapper for statsmodels regressors """
    def __init__(self, model_class, fit_intercept=True):
        self.model_class = model_class
        self.fit_intercept = fit_intercept
    def fit(self, X, y):
        if self.fit_intercept:
            X = sm.add_constant(X)
        self.model_ = self.model_class(y, X)
        self.results_ = self.model_.fit()
    def predict(self, X):
        if self.fit_intercept:
            X = sm.add_constant(X)
        return self.results_.predict(X)

df_train_macro = pd.read_csv('./data/train_macro.csv', index_col=0)
df_test_macro = pd.read_csv('./data/test_macro.csv', index_col=0)

sys.setrecursionlimit(1500)

degree = 2
skewness_limit = 1
num_of_cooks = 2
num_of_f_test = 10

# %% [markdown]
# # 1. Column Names
# ## Column Names
# Replace -, +, :, ~, * in column name with underscore

# %%
new_cols = []
for col in  list(df_train_macro.columns):
    col = col.replace('-', '_').replace('+', '_').replace(':', '_').replace('~', '_').replace('*', '_')
    new_cols.append('_'+col)
df_train_macro.columns = new_cols

new_cols = []
for col in list(df_test_macro.columns):
    col = col.replace('-', '_').replace('+', '_').replace(':', '_').replace('~', '_').replace('*', '_')
    new_cols.append('_'+col)
df_test_macro.columns = new_cols

categorial_ivs = list(set(df_train_macro.columns) - set(df_train_macro._get_numeric_data().columns))
numeric_ivs = df_train_macro._get_numeric_data().columns.drop('_price_doc').tolist()

# %% [markdown]
# ## Log Transformation
# Transform data with skewness greater than 1.

# %%
features_to_log = []
for f in df_train_macro._get_numeric_data().columns:
    skewness = sp.stats.skew(df_train_macro[f])
    if skewness > skewness_limit:
        features_to_log.append(f)

for col in df_train_macro._get_numeric_data().columns:
    if col != '_price_doc':
        min_val_train = min(df_train_macro[col])
        min_val_test  = min(df_test_macro[col])
        min_val = min(min_val_train, min_val_test)
        if min_val <= 0:
            df_train_macro[col] += (np.abs(min_val) + 0.1)
            df_test_macro[col]  += (np.abs(min_val) + 0.1)
    else:
        min_val_train = min(df_train_macro[col])
        if min_val_train <= 0:
            df_train_macro[col] += (np.abs(min_val_train) + 0.1)

# %%
formula = sh.make_statsmodels_ols_formula(numeric_ivs, categorial_ivs, '_price_doc', log_vs=features_to_log, degree=degree, scale=False)
model = sm.OLS.from_formula(formula, data=df_train_macro)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     np.log(_price_doc)   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     184.0
# Date:                Mon, 28 Oct 2019   Prob (F-statistic):               0.00
# Time:                        21:24:31   Log-Likelihood:                -20041.
# No. Observations:               30404   AIC:                         4.029e+04
# Df Residuals:                   30298   BIC:                         4.118e+04
# Df Model:                         105
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  6.9655      1.912      3.643      0.000       3.218      10.713
# C(_ecology)[T.good]                                       -0.0382      0.015     -2.568      0.010      -0.067      -0.009
# C(_ecology)[T.no data]                                    -0.1856      0.026     -7.107      0.000      -0.237      -0.134
# C(_ecology)[T.poor]                                       -0.0045      0.013     -0.349      0.727      -0.030       0.021
# C(_ecology)[T.satisfactory]                                0.0301      0.017      1.810      0.070      -0.002       0.063
# C(_water_1line)[T.yes]                                    -0.0003      0.012     -0.025      0.980      -0.023       0.022
# C(_nuclear_reactor_raion)[T.yes]                          -0.0311      0.019     -1.615      0.106      -0.069       0.007
# C(_big_road1_1line)[T.yes]                                -0.0233      0.019     -1.219      0.223      -0.061       0.014
# C(_radiation_raion)[T.yes]                                -0.0437      0.008     -5.184      0.000      -0.060      -0.027
# C(_incineration_raion)[T.yes]                             -0.0024      0.021     -0.114      0.910      -0.044       0.039
# C(_product_type)[T.OwnerOccupier]                          0.1279      0.011     11.642      0.000       0.106       0.149
# C(_railroad_terminal_raion)[T.yes]                         0.0332      0.027      1.215      0.224      -0.020       0.087
# C(_big_market_raion)[T.yes]                                0.0045      0.015      0.304      0.761      -0.025       0.034
# C(_railroad_1line)[T.yes]                                 -0.1927      0.018    -10.939      0.000      -0.227      -0.158
# C(_culture_objects_top_25)[T.yes]                          0.0827      0.017      4.749      0.000       0.049       0.117
# C(_thermal_power_plant_raion)[T.yes]                       0.0035      0.016      0.217      0.828      -0.028       0.035
# C(_oil_chemistry_raion)[T.yes]                            -0.0776      0.033     -2.346      0.019      -0.142      -0.013
# C(_detention_facility_raion)[T.yes]                       -0.0018      0.012     -0.143      0.886      -0.026       0.022
# np.log(_usdrub)                                            2.5691      0.538      4.771      0.000       1.514       3.624
# np.log(_full_sq)                                           0.3374      0.120      2.811      0.005       0.102       0.573
# np.log(_life_sq)                                           0.0034      0.012      0.286      0.775      -0.020       0.026
# _floor                                                     0.0079      0.002      5.003      0.000       0.005       0.011
# _num_room                                                 -0.0906      0.019     -4.676      0.000      -0.129      -0.053
# np.log(_kitch_sq)                                         -0.0007      0.003     -0.224      0.823      -0.007       0.006
# _state                                                    -0.1594      0.023     -6.943      0.000      -0.204      -0.114
# np.log(_area_m)                                            0.1859      0.201      0.927      0.354      -0.207       0.579
# np.log(_school_education_centers_top_20_raion)             0.2845      0.042      6.721      0.000       0.202       0.367
# np.log(_hospital_beds_raion)                              -0.0833      0.024     -3.420      0.001      -0.131      -0.036
# np.log(_healthcare_centers_raion)                          0.0132      0.005      2.825      0.005       0.004       0.022
# np.log(_university_top_20_raion)                          -0.0318      0.030     -1.053      0.292      -0.091       0.027
# np.log(_shopping_centers_raion)                            0.0031      0.004      0.773      0.439      -0.005       0.011
# np.log(_build_count_brick)                                -0.0039      0.003     -1.137      0.255      -0.011       0.003
# np.log(_build_count_monolith)                             -0.0059      0.003     -1.753      0.080      -0.012       0.001
# np.log(_build_count_before_1920)                          -0.0038      0.002     -1.547      0.122      -0.009       0.001
# np.log(_kindergarten_km)                                  -0.0079      0.006     -1.349      0.177      -0.019       0.004
# np.log(_public_transport_station_min_walk)                -0.0154      0.005     -2.898      0.004      -0.026      -0.005
# _big_road1_km                                              0.0239      0.010      2.407      0.016       0.004       0.043
# _big_road2_km                                             -0.0098      0.007     -1.406      0.160      -0.023       0.004
# np.log(_market_shop_km)                                   -0.0166      0.007     -2.508      0.012      -0.030      -0.004
# np.log(_fitness_km)                                       -0.0399      0.008     -5.277      0.000      -0.055      -0.025
# np.log(_hospice_morgue_km)                                 0.0105      0.005      2.044      0.041       0.000       0.021
# np.log(_office_km)                                         0.0002      0.010      0.021      0.983      -0.020       0.020
# np.log(_additional_education_km)                          -0.0007      0.005     -0.131      0.896      -0.011       0.010
# np.log(_church_synagogue_km)                              -0.0395      0.006     -6.151      0.000      -0.052      -0.027
# np.log(_catering_km)                                      -0.0483      0.007     -7.105      0.000      -0.062      -0.035
# np.log(_office_count_500)                                  0.0169      0.012      1.415      0.157      -0.007       0.040
# np.log(_office_sqm_500)                                    0.0067      0.007      1.000      0.317      -0.006       0.020
# np.log(_cafe_count_500_price_1000)                         0.0046      0.005      0.848      0.397      -0.006       0.015
# np.log(_cafe_count_500_price_1500)                        -0.0234      0.007     -3.505      0.000      -0.036      -0.010
# np.log(_leisure_count_500)                                 0.1658      0.020      8.373      0.000       0.127       0.205
# np.log(_office_sqm_1000)                                   0.0043      0.003      1.396      0.163      -0.002       0.010
# np.log(_cafe_count_1000_price_high)                        0.1443      0.022      6.455      0.000       0.100       0.188
# np.log(_leisure_count_1000)                               -0.0808      0.009     -8.996      0.000      -0.098      -0.063
# np.log(_sport_count_1000)                                 -0.0003      0.004     -0.082      0.935      -0.008       0.007
# np.log(_office_sqm_1500)                                  -0.0074      0.003     -2.471      0.013      -0.013      -0.002
# np.log(_trc_count_1500)                                    0.0088      0.004      2.204      0.028       0.001       0.017
# np.log(_mosque_count_1500)                                 0.5826      0.158      3.693      0.000       0.273       0.892
# np.log(_trc_sqm_2000)                                     -0.0024      0.003     -0.721      0.471      -0.009       0.004
# np.log(_mosque_count_2000)                                 0.5686      0.158      3.605      0.000       0.259       0.878
# np.log(_market_count_2000)                                -0.0025      0.006     -0.434      0.664      -0.014       0.009
# np.log(_trc_sqm_3000)                                     -0.0016      0.004     -0.428      0.669      -0.009       0.006
# _market_count_3000                                        -0.0011      0.007     -0.167      0.868      -0.014       0.012
# np.log(_mosque_count_5000)                                 0.0886      0.020      4.519      0.000       0.050       0.127
# I(np.log(_usdrub) ** 2)                                   -0.3133      0.071     -4.401      0.000      -0.453      -0.174
# I(np.log(_full_sq) ** 2)                                   0.0599      0.015      4.045      0.000       0.031       0.089
# I(np.log(_life_sq) ** 2)                                  -0.0010      0.002     -0.437      0.662      -0.005       0.003
# I(_floor ** 2)                                            -0.0001   7.14e-05     -1.817      0.069      -0.000    1.02e-05
# I(_num_room ** 2)                                          0.0229      0.004      5.522      0.000       0.015       0.031
# I(np.log(_kitch_sq) ** 2)                                  0.0073      0.002      4.572      0.000       0.004       0.010
# I(_state ** 2)                                             0.0455      0.005      8.965      0.000       0.036       0.055
# I(np.log(_area_m) ** 2)                                   -0.0060      0.006     -0.974      0.330      -0.018       0.006
# I(np.log(_school_education_centers_top_20_raion) ** 2)     0.1327      0.020      6.631      0.000       0.093       0.172
# I(np.log(_hospital_beds_raion) ** 2)                       0.0080      0.002      3.976      0.000       0.004       0.012
# I(np.log(_healthcare_centers_raion) ** 2)                 -0.0043      0.003     -1.458      0.145      -0.010       0.001
# I(np.log(_university_top_20_raion) ** 2)                  -0.0132      0.015     -0.907      0.365      -0.042       0.015
# I(np.log(_shopping_centers_raion) ** 2)                   -0.0029      0.002     -1.408      0.159      -0.007       0.001
# I(np.log(_build_count_brick) ** 2)                         0.0029      0.001      3.823      0.000       0.001       0.004
# I(np.log(_build_count_monolith) ** 2)                      0.0045      0.001      3.708      0.000       0.002       0.007
# I(np.log(_build_count_before_1920) ** 2)                  -0.0016      0.001     -1.841      0.066      -0.003       0.000
# I(np.log(_kindergarten_km) ** 2)                          -0.0022      0.001     -1.502      0.133      -0.005       0.001
# I(np.log(_public_transport_station_min_walk) ** 2)         0.0057      0.002      2.464      0.014       0.001       0.010
# I(_big_road1_km ** 2)                                     -0.0044      0.002     -2.188      0.029      -0.008      -0.000
# I(_big_road2_km ** 2)                                      0.0004      0.001      0.528      0.597      -0.001       0.002
# I(np.log(_market_shop_km) ** 2)                         5.112e-05      0.004      0.014      0.989      -0.007       0.007
# I(np.log(_fitness_km) ** 2)                               -0.0101      0.004     -2.339      0.019      -0.019      -0.002
# I(np.log(_hospice_morgue_km) ** 2)                        -0.0025      0.003     -0.823      0.411      -0.008       0.003
# I(np.log(_office_km) ** 2)                                -0.0059      0.004     -1.481      0.139      -0.014       0.002
# I(np.log(_additional_education_km) ** 2)                  -0.0196      0.004     -4.394      0.000      -0.028      -0.011
# I(np.log(_church_synagogue_km) ** 2)                      -0.0246      0.006     -4.471      0.000      -0.035      -0.014
# I(np.log(_catering_km) ** 2)                              -0.0062      0.002     -4.036      0.000      -0.009      -0.003
# I(np.log(_office_count_500) ** 2)                          0.0116      0.005      2.257      0.024       0.002       0.022
# I(np.log(_office_sqm_500) ** 2)                           -0.0004      0.001     -0.757      0.449      -0.002       0.001
# I(np.log(_cafe_count_500_price_1000) ** 2)                -0.0012      0.003     -0.411      0.681      -0.007       0.004
# I(np.log(_cafe_count_500_price_1500) ** 2)                -0.0124      0.003     -3.632      0.000      -0.019      -0.006
# I(np.log(_leisure_count_500) ** 2)                         0.0784      0.010      7.915      0.000       0.059       0.098
# I(np.log(_office_sqm_1000) ** 2)                          -0.0003      0.000     -0.940      0.347      -0.001       0.000
# I(np.log(_cafe_count_1000_price_high) ** 2)                0.0515      0.012      4.445      0.000       0.029       0.074
# I(np.log(_leisure_count_1000) ** 2)                       -0.0420      0.004     -9.421      0.000      -0.051      -0.033
# I(np.log(_sport_count_1000) ** 2)                          0.0023      0.002      1.241      0.215      -0.001       0.006
# I(np.log(_office_sqm_1500) ** 2)                           0.0007      0.000      2.260      0.024    9.65e-05       0.001
# I(np.log(_trc_count_1500) ** 2)                           -0.0047      0.002     -2.190      0.029      -0.009      -0.000
# I(np.log(_mosque_count_1500) ** 2)                         0.2427      0.072      3.393      0.001       0.103       0.383
# I(np.log(_trc_sqm_2000) ** 2)                            8.18e-05      0.000      0.269      0.788      -0.001       0.001
# I(np.log(_mosque_count_2000) ** 2)                         0.2737      0.072      3.825      0.000       0.133       0.414
# I(np.log(_market_count_2000) ** 2)                         0.0064      0.003      2.174      0.030       0.001       0.012
# I(np.log(_trc_sqm_3000) ** 2)                              0.0005      0.000      1.501      0.133      -0.000       0.001
# I(_market_count_3000 ** 2)                                 0.0008      0.001      0.993      0.321      -0.001       0.002
# I(np.log(_mosque_count_5000) ** 2)                         0.0306      0.009      3.311      0.001       0.012       0.049
# ==============================================================================
# Omnibus:                    14756.149   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            80275.479
# Skew:                          -2.361   Prob(JB):                         0.00
# Kurtosis:                       9.408   Cond. No.                     1.02e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.83e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Condition Number
# Large condition number occurs when the scale of data changes significantly due to the unit difference. Scaling can decrease condition number. Multicollinearity can also cause large condition number. We can handle this by reducing dimensionality with variance inflation factor.

# %% [markdown]
# ## Standard Scaling
# Standalize variables by removing the mean and scaling to unit variance.

# %%
formula = sh.make_statsmodels_ols_formula(numeric_ivs, categorial_ivs, '_price_doc', log_vs=features_to_log, degree=degree, scale=True)
model = sm.OLS.from_formula(formula, data=df_train_macro)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     np.log(_price_doc)   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     184.0
# Date:                Mon, 28 Oct 2019   Prob (F-statistic):               0.00
# Time:                        21:25:02   Log-Likelihood:                -20041.
# No. Observations:               30404   AIC:                         4.029e+04
# Df Residuals:                   30298   BIC:                         4.118e+04
# Df Model:                         105
# Covariance Type:            nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                        15.6357      0.015   1028.866      0.000      15.606      15.665
# C(_ecology)[T.good]                                              -0.0382      0.015     -2.568      0.010      -0.067      -0.009
# C(_ecology)[T.no data]                                           -0.1856      0.026     -7.107      0.000      -0.237      -0.134
# C(_ecology)[T.poor]                                              -0.0045      0.013     -0.349      0.727      -0.030       0.021
# C(_ecology)[T.satisfactory]                                       0.0301      0.017      1.810      0.070      -0.002       0.063
# C(_water_1line)[T.yes]                                           -0.0003      0.012     -0.025      0.980      -0.023       0.022
# C(_nuclear_reactor_raion)[T.yes]                                 -0.0311      0.019     -1.615      0.106      -0.069       0.007
# C(_big_road1_1line)[T.yes]                                       -0.0233      0.019     -1.219      0.223      -0.061       0.014
# C(_radiation_raion)[T.yes]                                       -0.0437      0.008     -5.184      0.000      -0.060      -0.027
# C(_incineration_raion)[T.yes]                                    -0.0024      0.021     -0.114      0.910      -0.044       0.039
# C(_product_type)[T.OwnerOccupier]                                 0.1279      0.011     11.642      0.000       0.106       0.149
# C(_railroad_terminal_raion)[T.yes]                                0.0332      0.027      1.215      0.224      -0.020       0.087
# C(_big_market_raion)[T.yes]                                       0.0045      0.015      0.304      0.761      -0.025       0.034
# C(_railroad_1line)[T.yes]                                        -0.1927      0.018    -10.939      0.000      -0.227      -0.158
# C(_culture_objects_top_25)[T.yes]                                 0.0827      0.017      4.749      0.000       0.049       0.117
# C(_thermal_power_plant_raion)[T.yes]                              0.0035      0.016      0.217      0.828      -0.028       0.035
# C(_oil_chemistry_raion)[T.yes]                                   -0.0776      0.033     -2.346      0.019      -0.142      -0.013
# C(_detention_facility_raion)[T.yes]                              -0.0018      0.012     -0.143      0.886      -0.026       0.022
# scale(np.log(_usdrub))                                            0.5595      0.117      4.771      0.000       0.330       0.789
# scale(np.log(_full_sq))                                           0.1176      0.042      2.811      0.005       0.036       0.200
# scale(np.log(_life_sq))                                           0.0020      0.007      0.286      0.775      -0.012       0.016
# scale(_floor)                                                     0.0418      0.008      5.003      0.000       0.025       0.058
# scale(_num_room)                                                 -0.0622      0.013     -4.676      0.000      -0.088      -0.036
# scale(np.log(_kitch_sq))                                         -0.0009      0.004     -0.224      0.823      -0.009       0.007
# scale(_state)                                                    -0.1010      0.015     -6.943      0.000      -0.129      -0.072
# scale(np.log(_area_m))                                            0.1497      0.161      0.927      0.354      -0.167       0.466
# scale(np.log(_school_education_centers_top_20_raion))             0.2115      0.031      6.721      0.000       0.150       0.273
# scale(np.log(_hospital_beds_raion))                              -0.0763      0.022     -3.420      0.001      -0.120      -0.033
# scale(np.log(_healthcare_centers_raion))                          0.0204      0.007      2.825      0.005       0.006       0.035
# scale(np.log(_university_top_20_raion))                          -0.0254      0.024     -1.053      0.292      -0.073       0.022
# scale(np.log(_shopping_centers_raion))                            0.0054      0.007      0.773      0.439      -0.008       0.019
# scale(np.log(_build_count_brick))                                -0.0119      0.010     -1.137      0.255      -0.032       0.009
# scale(np.log(_build_count_monolith))                             -0.0123      0.007     -1.753      0.080      -0.026       0.001
# scale(np.log(_build_count_before_1920))                          -0.0089      0.006     -1.547      0.122      -0.020       0.002
# scale(np.log(_kindergarten_km))                                  -0.0095      0.007     -1.349      0.177      -0.023       0.004
# scale(np.log(_public_transport_station_min_walk))                -0.0159      0.005     -2.898      0.004      -0.027      -0.005
# scale(_big_road1_km)                                              0.0311      0.013      2.407      0.016       0.006       0.056
# scale(_big_road2_km)                                             -0.0183      0.013     -1.406      0.160      -0.044       0.007
# scale(np.log(_market_shop_km))                                   -0.0144      0.006     -2.508      0.012      -0.026      -0.003
# scale(np.log(_fitness_km))                                       -0.0333      0.006     -5.277      0.000      -0.046      -0.021
# scale(np.log(_hospice_morgue_km))                                 0.0089      0.004      2.044      0.041       0.000       0.017
# scale(np.log(_office_km))                                         0.0002      0.010      0.021      0.983      -0.020       0.020
# scale(np.log(_additional_education_km))                          -0.0006      0.005     -0.131      0.896      -0.010       0.009
# scale(np.log(_church_synagogue_km))                              -0.0242      0.004     -6.151      0.000      -0.032      -0.016
# scale(np.log(_catering_km))                                      -0.0539      0.008     -7.105      0.000      -0.069      -0.039
# scale(np.log(_office_count_500))                                  0.0229      0.016      1.415      0.157      -0.009       0.055
# scale(np.log(_office_sqm_500))                                    0.0354      0.035      1.000      0.317      -0.034       0.105
# scale(np.log(_cafe_count_500_price_1000))                         0.0068      0.008      0.848      0.397      -0.009       0.023
# scale(np.log(_cafe_count_500_price_1500))                        -0.0333      0.009     -3.505      0.000      -0.052      -0.015
# scale(np.log(_leisure_count_500))                                 0.0954      0.011      8.373      0.000       0.073       0.118
# scale(np.log(_office_sqm_1000))                                   0.0285      0.020      1.396      0.163      -0.012       0.069
# scale(np.log(_cafe_count_1000_price_high))                        0.0776      0.012      6.455      0.000       0.054       0.101
# scale(np.log(_leisure_count_1000))                               -0.0915      0.010     -8.996      0.000      -0.111      -0.072
# scale(np.log(_sport_count_1000))                                 -0.0005      0.006     -0.082      0.935      -0.013       0.012
# scale(np.log(_office_sqm_1500))                                  -0.0495      0.020     -2.471      0.013      -0.089      -0.010
# scale(np.log(_trc_count_1500))                                    0.0151      0.007      2.204      0.028       0.002       0.028
# scale(np.log(_mosque_count_1500))                                 0.0107      0.002      5.340      0.000       0.007       0.015
# scale(np.log(_trc_sqm_2000))                                     -0.0140      0.019     -0.721      0.471      -0.052       0.024
# scale(np.log(_mosque_count_2000))                                -0.0121      0.002     -4.843      0.000      -0.017      -0.007
# scale(np.log(_market_count_2000))                                -0.0038      0.009     -0.434      0.664      -0.021       0.014
# scale(np.log(_trc_sqm_3000))                                     -0.0082      0.019     -0.428      0.669      -0.046       0.029
# scale(_market_count_3000)                                        -0.0025      0.015     -0.167      0.868      -0.032       0.027
# scale(np.log(_mosque_count_5000))                                 0.1085      0.024      4.519      0.000       0.061       0.156
# scale(I(np.log(_usdrub) ** 2))                                   -0.5131      0.117     -4.401      0.000      -0.742      -0.285
# scale(I(np.log(_full_sq) ** 2))                                   0.1679      0.042      4.045      0.000       0.087       0.249
# scale(I(np.log(_life_sq) ** 2))                                  -0.0034      0.008     -0.437      0.662      -0.019       0.012
# scale(I(_floor ** 2))                                            -0.0151      0.008     -1.817      0.069      -0.031       0.001
# scale(I(_num_room ** 2))                                          0.0714      0.013      5.522      0.000       0.046       0.097
# scale(I(np.log(_kitch_sq) ** 2))                                  0.0177      0.004      4.572      0.000       0.010       0.025
# scale(I(_state ** 2))                                             0.1269      0.014      8.965      0.000       0.099       0.155
# scale(I(np.log(_area_m) ** 2))                                   -0.1594      0.164     -0.974      0.330      -0.480       0.161
# scale(I(np.log(_school_education_centers_top_20_raion) ** 2))     0.2121      0.032      6.631      0.000       0.149       0.275
# scale(I(np.log(_hospital_beds_raion) ** 2))                       0.0891      0.022      3.976      0.000       0.045       0.133
# scale(I(np.log(_healthcare_centers_raion) ** 2))                 -0.0098      0.007     -1.458      0.145      -0.023       0.003
# scale(I(np.log(_university_top_20_raion) ** 2))                  -0.0203      0.022     -0.907      0.365      -0.064       0.024
# scale(I(np.log(_shopping_centers_raion) ** 2))                   -0.0067      0.005     -1.408      0.159      -0.016       0.003
# scale(I(np.log(_build_count_brick) ** 2))                         0.0312      0.008      3.823      0.000       0.015       0.047
# scale(I(np.log(_build_count_monolith) ** 2))                      0.0186      0.005      3.708      0.000       0.009       0.028
# scale(I(np.log(_build_count_before_1920) ** 2))                  -0.0099      0.005     -1.841      0.066      -0.020       0.001
# scale(I(np.log(_kindergarten_km) ** 2))                          -0.0069      0.005     -1.502      0.133      -0.016       0.002
# scale(I(np.log(_public_transport_station_min_walk) ** 2))         0.0191      0.008      2.464      0.014       0.004       0.034
# scale(I(_big_road1_km ** 2))                                     -0.0274      0.013     -2.188      0.029      -0.052      -0.003
# scale(I(_big_road2_km ** 2))                                      0.0068      0.013      0.528      0.597      -0.019       0.032
# scale(I(np.log(_market_shop_km) ** 2))                         9.444e-05      0.007      0.014      0.989      -0.014       0.014
# scale(I(np.log(_fitness_km) ** 2))                               -0.0096      0.004     -2.339      0.019      -0.018      -0.002
# scale(I(np.log(_hospice_morgue_km) ** 2))                        -0.0038      0.005     -0.823      0.411      -0.013       0.005
# scale(I(np.log(_office_km) ** 2))                                -0.0080      0.005     -1.481      0.139      -0.019       0.003
# scale(I(np.log(_additional_education_km) ** 2))                  -0.0219      0.005     -4.394      0.000      -0.032      -0.012
# scale(I(np.log(_church_synagogue_km) ** 2))                      -0.0172      0.004     -4.471      0.000      -0.025      -0.010
# scale(I(np.log(_catering_km) ** 2))                              -0.0225      0.006     -4.036      0.000      -0.033      -0.012
# scale(I(np.log(_office_count_500) ** 2))                          0.0223      0.010      2.257      0.024       0.003       0.042
# scale(I(np.log(_office_sqm_500) ** 2))                           -0.0190      0.025     -0.757      0.449      -0.068       0.030
# scale(I(np.log(_cafe_count_500_price_1000) ** 2))                -0.0028      0.007     -0.411      0.681      -0.016       0.010
# scale(I(np.log(_cafe_count_500_price_1500) ** 2))                -0.0279      0.008     -3.632      0.000      -0.043      -0.013
# scale(I(np.log(_leisure_count_500) ** 2))                         0.0885      0.011      7.915      0.000       0.067       0.110
# scale(I(np.log(_office_sqm_1000) ** 2))                          -0.0212      0.023     -0.940      0.347      -0.065       0.023
# scale(I(np.log(_cafe_count_1000_price_high) ** 2))                0.0544      0.012      4.445      0.000       0.030       0.078
# scale(I(np.log(_leisure_count_1000) ** 2))                       -0.0737      0.008     -9.421      0.000      -0.089      -0.058
# scale(I(np.log(_sport_count_1000) ** 2))                          0.0051      0.004      1.241      0.215      -0.003       0.013
# scale(I(np.log(_office_sqm_1500) ** 2))                           0.0482      0.021      2.260      0.024       0.006       0.090
# scale(I(np.log(_trc_count_1500) ** 2))                           -0.0108      0.005     -2.190      0.029      -0.021      -0.001
# scale(I(np.log(_mosque_count_1500) ** 2))                        -0.0107      0.002     -5.340      0.000      -0.015      -0.007
# scale(I(np.log(_trc_sqm_2000) ** 2))                              0.0050      0.019      0.269      0.788      -0.032       0.042
# scale(I(np.log(_mosque_count_2000) ** 2))                         0.0121      0.002      4.843      0.000       0.007       0.017
# scale(I(np.log(_market_count_2000) ** 2))                         0.0152      0.007      2.174      0.030       0.002       0.029
# scale(I(np.log(_trc_sqm_3000) ** 2))                              0.0322      0.021      1.501      0.133      -0.010       0.074
# scale(I(_market_count_3000 ** 2))                                 0.0124      0.013      0.993      0.321      -0.012       0.037
# scale(I(np.log(_mosque_count_5000) ** 2))                         0.0773      0.023      3.311      0.001       0.032       0.123
# ==============================================================================
# Omnibus:                    14756.149   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            80275.479
# Skew:                          -2.361   Prob(JB):                         0.00
# Kurtosis:                       9.408   Cond. No.                     1.37e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.5e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# Scaling did not significantly decrease the condition number.

# %% [markdown]
# # 2. Dimensionality Reduction
# ## ANOVA

# %%
anova = sm.stats.anova_lm(result, typ=2)
anova
# Out:
#                                                          sum_sq       df  \
# C(_ecology)                                           21.266066      4.0
# C(_water_1line)                                        0.000138      1.0
# C(_nuclear_reactor_raion)                              0.572989      1.0
# C(_big_road1_1line)                                    0.326130      1.0
# C(_radiation_raion)                                    5.900100      1.0
# C(_incineration_raion)                                 0.002834      1.0
# C(_product_type)                                      29.757188      1.0
# C(_railroad_terminal_raion)                            0.324087      1.0
# C(_big_market_raion)                                   0.020281      1.0
# C(_railroad_1line)                                    26.271992      1.0
# C(_culture_objects_top_25)                             4.951454      1.0
# C(_thermal_power_plant_raion)                          0.010368      1.0
# C(_oil_chemistry_raion)                                1.208267      1.0
# C(_detention_facility_raion)                           0.004518      1.0
# scale(np.log(_usdrub))                                 4.998635      1.0
# scale(np.log(_full_sq))                                1.735187      1.0
# scale(np.log(_life_sq))                                0.017946      1.0
# scale(_floor)                                          5.495845      1.0
# scale(_num_room)                                       4.800988      1.0
# scale(np.log(_kitch_sq))                               0.011011      1.0
# scale(_state)                                         10.583895      1.0
# scale(np.log(_area_m))                                 0.188640      1.0
# scale(np.log(_school_education_centers_top_20_r...     9.917043      1.0
# scale(np.log(_hospital_beds_raion))                    2.567816      1.0
# scale(np.log(_healthcare_centers_raion))               1.752211      1.0
# scale(np.log(_university_top_20_raion))                0.243679      1.0
# scale(np.log(_shopping_centers_raion))                 0.131335      1.0
# scale(np.log(_build_count_brick))                      0.284033      1.0
# scale(np.log(_build_count_monolith))                   0.675097      1.0
# scale(np.log(_build_count_before_1920))                0.525713      1.0
# scale(np.log(_kindergarten_km))                        0.399340      1.0
# scale(np.log(_public_transport_station_min_walk))      1.844282      1.0
# scale(_big_road1_km)                                   1.272165      1.0
# scale(_big_road2_km)                                   0.434206      1.0
# scale(np.log(_market_shop_km))                         1.381553      1.0
# scale(np.log(_fitness_km))                             6.114197      1.0
# scale(np.log(_hospice_morgue_km))                      0.917675      1.0
# scale(np.log(_office_km))                              0.000100      1.0
# scale(np.log(_additional_education_km))                0.003742      1.0
# scale(np.log(_church_synagogue_km))                    8.306778      1.0
# scale(np.log(_catering_km))                           11.083157      1.0
# scale(np.log(_office_count_500))                       0.439384      1.0
# scale(np.log(_office_sqm_500))                         0.219551      1.0
# scale(np.log(_cafe_count_500_price_1000))              0.157757      1.0
# scale(np.log(_cafe_count_500_price_1500))              2.697152      1.0
# scale(np.log(_leisure_count_500))                     15.392124      1.0
# scale(np.log(_office_sqm_1000))                        0.427784      1.0
# scale(np.log(_cafe_count_1000_price_high))             9.148791      1.0
# scale(np.log(_leisure_count_1000))                    17.768550      1.0
# scale(np.log(_sport_count_1000))                       0.001475      1.0
# scale(np.log(_office_sqm_1500))                        1.340254      1.0
# scale(np.log(_trc_count_1500))                         1.066768      1.0
# scale(np.log(_mosque_count_1500))                      6.260382      1.0
# scale(np.log(_trc_sqm_2000))                           0.114158      1.0
# scale(np.log(_mosque_count_2000))                      5.149707      1.0
# scale(np.log(_market_count_2000))                      0.041340      1.0
# scale(np.log(_trc_sqm_3000))                           0.040145      1.0
# scale(_market_count_3000)                              0.006101      1.0
# scale(np.log(_mosque_count_5000))                      4.482895      1.0
# scale(I(np.log(_usdrub) ** 2))                         4.252745      1.0
# scale(I(np.log(_full_sq) ** 2))                        3.592105      1.0
# scale(I(np.log(_life_sq) ** 2))                        0.041961      1.0
# scale(I(_floor ** 2))                                  0.724979      1.0
# scale(I(_num_room ** 2))                               6.696030      1.0
# scale(I(np.log(_kitch_sq) ** 2))                       4.589325      1.0
# scale(I(_state ** 2))                                 17.646694      1.0
# scale(I(np.log(_area_m) ** 2))                         0.208479      1.0
# scale(I(np.log(_school_education_centers_top_20...     9.655068      1.0
# scale(I(np.log(_hospital_beds_raion) ** 2))            3.471449      1.0
# scale(I(np.log(_healthcare_centers_raion) ** 2))       0.466661      1.0
# scale(I(np.log(_university_top_20_raion) ** 2))        0.180523      1.0
# scale(I(np.log(_shopping_centers_raion) ** 2))         0.435396      1.0
# scale(I(np.log(_build_count_brick) ** 2))              3.209016      1.0
# scale(I(np.log(_build_count_monolith) ** 2))           3.018657      1.0
# scale(I(np.log(_build_count_before_1920) ** 2))        0.744033      1.0
# scale(I(np.log(_kindergarten_km) ** 2))                0.495673      1.0
# scale(I(np.log(_public_transport_station_min_wa...     1.333434      1.0
# scale(I(_big_road1_km ** 2))                           1.051468      1.0
# scale(I(_big_road2_km ** 2))                           0.061292      1.0
# scale(I(np.log(_market_shop_km) ** 2))                 0.000040      1.0
# scale(I(np.log(_fitness_km) ** 2))                     1.200841      1.0
# scale(I(np.log(_hospice_morgue_km) ** 2))              0.148627      1.0
# scale(I(np.log(_office_km) ** 2))                      0.481566      1.0
# scale(I(np.log(_additional_education_km) ** 2))        4.239994      1.0
# scale(I(np.log(_church_synagogue_km) ** 2))            4.389900      1.0
# scale(I(np.log(_catering_km) ** 2))                    3.576352      1.0
# scale(I(np.log(_office_count_500) ** 2))               1.118749      1.0
# scale(I(np.log(_office_sqm_500) ** 2))                 0.125680      1.0
# scale(I(np.log(_cafe_count_500_price_1000) ** 2))      0.037157      1.0
# scale(I(np.log(_cafe_count_500_price_1500) ** 2))      2.896217      1.0
# scale(I(np.log(_leisure_count_500) ** 2))             13.755307      1.0
# scale(I(np.log(_office_sqm_1000) ** 2))                0.193909      1.0
# scale(I(np.log(_cafe_count_1000_price_high) ** 2))     4.338224      1.0
# scale(I(np.log(_leisure_count_1000) ** 2))            19.486700      1.0
# scale(I(np.log(_sport_count_1000) ** 2))               0.337885      1.0
# scale(I(np.log(_office_sqm_1500) ** 2))                1.121849      1.0
# scale(I(np.log(_trc_count_1500) ** 2))                 1.053256      1.0
# scale(I(np.log(_mosque_count_1500) ** 2))              6.260382      1.0
# scale(I(np.log(_trc_sqm_2000) ** 2))                   0.015884      1.0
# scale(I(np.log(_mosque_count_2000) ** 2))              5.149707      1.0
# scale(I(np.log(_market_count_2000) ** 2))              1.037969      1.0
# scale(I(np.log(_trc_sqm_3000) ** 2))                   0.494943      1.0
# scale(I(_market_count_3000 ** 2))                      0.216550      1.0
# scale(I(np.log(_mosque_count_5000) ** 2))              2.406420      1.0
# Residual                                            6652.441932  30298.0
#
#                                                              F        PR(>F)
# C(_ecology)                                          24.213637  4.948295e-20
# C(_water_1line)                                       0.000627  9.800251e-01
# C(_nuclear_reactor_raion)                             2.609631  1.062269e-01
# C(_big_road1_1line)                                   1.485333  2.229515e-01
# C(_radiation_raion)                                  26.871520  2.188339e-07
# C(_incineration_raion)                                0.012908  9.095442e-01
# C(_product_type)                                    135.526667  2.952085e-31
# C(_railroad_terminal_raion)                           1.476029  2.244063e-01
# C(_big_market_raion)                                  0.092369  7.611883e-01
# C(_railroad_1line)                                  119.653629  8.491574e-28
# C(_culture_objects_top_25)                           22.550990  2.055743e-06
# C(_thermal_power_plant_raion)                         0.047218  8.279783e-01
# C(_oil_chemistry_raion)                               5.502953  1.899080e-02
# C(_detention_facility_raion)                          0.020578  8.859354e-01
# scale(np.log(_usdrub))                               22.765873  1.838382e-06
# scale(np.log(_full_sq))                               7.902768  4.939089e-03
# scale(np.log(_life_sq))                               0.081736  7.749610e-01
# scale(_floor)                                        25.030373  5.674971e-07
# scale(_num_room)                                     21.865705  2.936730e-06
# scale(np.log(_kitch_sq))                              0.050151  8.228027e-01
# scale(_state)                                        48.203482  3.919436e-12
# scale(np.log(_area_m))                                0.859147  3.539848e-01
# scale(np.log(_school_education_centers_top_20_r...   45.166359  1.841926e-11
# scale(np.log(_hospital_beds_raion))                  11.694908  6.275391e-04
# scale(np.log(_healthcare_centers_raion))              7.980303  4.731992e-03
# scale(np.log(_university_top_20_raion))               1.109815  2.921306e-01
# scale(np.log(_shopping_centers_raion))                0.598154  4.392893e-01
# scale(np.log(_build_count_brick))                     1.293604  2.553939e-01
# scale(np.log(_build_count_monolith))                  3.074676  7.953055e-02
# scale(np.log(_build_count_before_1920))               2.394316  1.217874e-01
# scale(np.log(_kindergarten_km))                       1.818762  1.774707e-01
# scale(np.log(_public_transport_station_min_walk))     8.399633  3.755658e-03
# scale(_big_road1_km)                                  5.793970  1.608717e-02
# scale(_big_road2_km)                                  1.977557  1.596583e-01
# scale(np.log(_market_shop_km))                        6.292168  1.213245e-02
# scale(np.log(_fitness_km))                           27.846607  1.322265e-07
# scale(np.log(_hospice_morgue_km))                     4.179476  4.092496e-02
# scale(np.log(_office_km))                             0.000457  9.829528e-01
# scale(np.log(_additional_education_km))               0.017043  8.961332e-01
# scale(np.log(_church_synagogue_km))                  37.832539  7.804841e-10
# scale(np.log(_catering_km))                          50.477327  1.232095e-12
# scale(np.log(_office_count_500))                      2.001140  1.571912e-01
# scale(np.log(_office_sqm_500))                        0.999928  3.173360e-01
# scale(np.log(_cafe_count_500_price_1000))             0.718490  3.966464e-01
# scale(np.log(_cafe_count_500_price_1500))            12.283956  4.575285e-04
# scale(np.log(_leisure_count_500))                    70.102164  5.870521e-17
# scale(np.log(_office_sqm_1000))                       1.948309  1.627794e-01
# scale(np.log(_cafe_count_1000_price_high))           41.667417  1.098316e-10
# scale(np.log(_leisure_count_1000))                   80.925400  2.477209e-19
# scale(np.log(_sport_count_1000))                      0.006719  9.346723e-01
# scale(np.log(_office_sqm_1500))                       6.104079  1.349248e-02
# scale(np.log(_trc_count_1500))                        4.858508  2.751760e-02
# scale(np.log(_mosque_count_1500))                    28.512396  9.377023e-08
# scale(np.log(_trc_sqm_2000))                          0.519924  4.708796e-01
# scale(np.log(_mosque_count_2000))                    23.453916  1.285727e-06
# scale(np.log(_market_count_2000))                     0.188279  6.643562e-01
# scale(np.log(_trc_sqm_3000))                          0.182839  6.689478e-01
# scale(_market_count_3000)                             0.027785  8.676173e-01
# scale(np.log(_mosque_count_5000))                    20.416978  6.251001e-06
# scale(I(np.log(_usdrub) ** 2))                       19.368779  1.081222e-05
# scale(I(np.log(_full_sq) ** 2))                      16.359948  5.251014e-05
# scale(I(np.log(_life_sq) ** 2))                       0.191110  6.619977e-01
# scale(I(_floor ** 2))                                 3.301858  6.921145e-02
# scale(I(_num_room ** 2))                             30.496517  3.372087e-08
# scale(I(np.log(_kitch_sq) ** 2))                     20.901704  4.853740e-06
# scale(I(_state ** 2))                                80.370417  3.278016e-19
# scale(I(np.log(_area_m) ** 2))                        0.949500  3.298545e-01
# scale(I(np.log(_school_education_centers_top_20...   43.973215  3.384922e-11
# scale(I(np.log(_hospital_beds_raion) ** 2))          15.810430  7.017793e-05
# scale(I(np.log(_healthcare_centers_raion) ** 2))      2.125370  1.448882e-01
# scale(I(np.log(_university_top_20_raion) ** 2))       0.822176  3.645520e-01
# scale(I(np.log(_shopping_centers_raion) ** 2))        1.982976  1.590875e-01
# scale(I(np.log(_build_count_brick) ** 2))            14.615199  1.321106e-04
# scale(I(np.log(_build_count_monolith) ** 2))         13.748226  2.093907e-04
# scale(I(np.log(_build_count_before_1920) ** 2))       3.388636  6.565700e-02
# scale(I(np.log(_kindergarten_km) ** 2))               2.257501  1.329789e-01
# scale(I(np.log(_public_transport_station_min_wa...    6.073014  1.373176e-02
# scale(I(_big_road1_km ** 2))                          4.788823  2.865260e-02
# scale(I(_big_road2_km ** 2))                          0.279147  5.972646e-01
# scale(I(np.log(_market_shop_km) ** 2))                0.000184  9.891897e-01
# scale(I(np.log(_fitness_km) ** 2))                    5.469130  1.936173e-02
# scale(I(np.log(_hospice_morgue_km) ** 2))             0.676909  4.106595e-01
# scale(I(np.log(_office_km) ** 2))                     2.193252  1.386267e-01
# scale(I(np.log(_additional_education_km) ** 2))      19.310704  1.114589e-05
# scale(I(np.log(_church_synagogue_km) ** 2))          19.993438  7.799027e-06
# scale(I(np.log(_catering_km) ** 2))                  16.288199  5.453523e-05
# scale(I(np.log(_office_count_500) ** 2))              5.095248  2.399857e-02
# scale(I(np.log(_office_sqm_500) ** 2))                0.572401  4.493124e-01
# scale(I(np.log(_cafe_count_500_price_1000) ** 2))     0.169229  6.808010e-01
# scale(I(np.log(_cafe_count_500_price_1500) ** 2))    13.190581  2.818237e-04
# scale(I(np.log(_leisure_count_500) ** 2))            62.647416  2.556171e-15
# scale(I(np.log(_office_sqm_1000) ** 2))               0.883143  3.473498e-01
# scale(I(np.log(_cafe_count_1000_price_high) ** 2))   19.758086  8.820074e-06
# scale(I(np.log(_leisure_count_1000) ** 2))           88.750574  4.785779e-21
# scale(I(np.log(_sport_count_1000) ** 2))              1.538871  2.147955e-01
# scale(I(np.log(_office_sqm_1500) ** 2))               5.109369  2.380404e-02
# scale(I(np.log(_trc_count_1500) ** 2))                4.796966  2.851749e-02
# scale(I(np.log(_mosque_count_1500) ** 2))            28.512396  9.377023e-08
# scale(I(np.log(_trc_sqm_2000) ** 2))                  0.072341  7.879608e-01
# scale(I(np.log(_mosque_count_2000) ** 2))            23.453916  1.285727e-06
# scale(I(np.log(_market_count_2000) ** 2))             4.727345  2.969439e-02
# scale(I(np.log(_trc_sqm_3000) ** 2))                  2.254177  1.332647e-01
# scale(I(_market_count_3000 ** 2))                     0.986261  3.206658e-01
# scale(I(np.log(_mosque_count_5000) ** 2))            10.959841  9.321653e-04
# Residual                                                   NaN           NaN

# %% [markdown]
# We can remove features with p-value equal or greater than 0.05 since they have very small influences on the dependent variable

# %% [markdown]
# ## F-test and Feature Influence

# %%
result, sms_vars, formula = fs.by_f_test(df_train_macro, formula, repeat=num_of_f_test)
result.summary()

# %% [markdown]
# # 3. Outlier
# ## Cook's Distance
# - Find data with large leverage and residual by calculating Cook's distance.

# %%
df_train_macro_with_outliers = df_train_macro.copy(deep=True)
df_train_macro, model, result = pp.remove_outliers(df_train_macro, formula, repeat=3)
result.summary()

# %% [markdown]
# # 4. Regularization
# ## Lasso
# Find variables with zero coefficient when Lasso regularization is applied.

# %%
result_lasso = model.fit_regularized(alpha=0.001, L1_wt=1)

# %% [markdown]
# Let's remove features with zero coefficient to reduce dimensionality.

# %%
sms_vars = []
for idx, coef in enumerate(result_lasso.params):
    if coef ==0:
        continue
    feature = result_lasso.params.index[idx]
    if feature == 'Intercept':
        continue
    startDelPos = feature.find('[')
    endDelPos = feature.find(']')
    feature = feature.replace(feature[startDelPos:endDelPos+1], '')
    sms_vars.append(feature)

# %%
formula = 'np.log(_price_doc) ~ ' + " + ".join(sms_vars)
model = sm.OLS.from_formula(formula, data=df_train_macro)
result = model.fit()
result.summary()

# %% [markdown]
# # 5. Diagnosis of Regression
# ## Residual Normality Test

# %%
# outlier remove result 
sp.stats.probplot(result.resid, plot=plt)
plt.show()

# %%
test = sms.omni_normtest(result.resid)
for xi in zip(['Chi^2', 'P-value'], test):
    print("%-12s: %6.3f" % xi)

# %% [markdown]
# # Partial Regression Plot
# Let's visualize the influence of a single independent variable.

# %%
fig = plt.figure(figsize=(10,70))
sm.graphics.plot_partregress_grid(result, fig=fig)
fig.suptitle("")
plt.show()

# %% [markdown]
# # 6. Cross Validation

# %%
dm = dmatrix(" + ".join(sms_vars) + ' + np.log(_price_doc)', df_train_macro_with_outliers, return_type="dataframe")
X = dm[dm.columns.drop(['np.log(_price_doc)'])]
y = dm['np.log(_price_doc)']
cv = cv = KFold(n_splits=1000, shuffle=True, random_state=0)
r2s = cross_val_score(SMWrapper(sm.OLS), X, y, scoring='r2', cv=cv)
r2s.mean()

# %%
plt.hist(r2s, bins=100)

# %%
y_pred = np.exp(result.predict(df_test_macro))
y_pred = y_pred.to_frame('price_doc')
y_pred.to_csv('./data/stats_models_{}.csv'.format(datetime.datetime.now().strftime('%Y_%m_%d_%H_%M_%S')), header=True, index=True)

# %% [markdown]
# ## Score

# %%
real = pd.read_csv('./data/sample_submission.csv', index_col=0)
score = ec.rmsle(y_pred, real)
score
