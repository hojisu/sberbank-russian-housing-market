# %% [markdown]
# # Modeling with StatsModels

# %% [markdown]
# ## 1. Ordinary Least Square
# - Column Names
# - Log Transformation
# - Condition Number
# - Standard Scaling

# %% [markdown]
# # 2. Dimensionality Reduction
# - ANOVA
# - F-test and Feature Influence

# %% [markdown]
# # 3. Outlier
# - Cook's Distance

# %% [markdown]
# # 4. Regularization
# - Lasso

# %% [markdown]
# # 5. Diagnosis of Regression
# - Residual Normality Test
# - Partial Regression Plot

# %% [markdown]
# # 6. Cross Validatoin

# %% [markdown]
# # 7. Test
# - score

# %%
# %matplotlib inline
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
import warnings
import sys
import datetime
import scipy as sp
import statsmodels.stats.api as sms
import statsmodels.api as sm
from patsy import dmatrix
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
import utils.statsmodel_helper as sh
import utils.feature_selection as fs
import utils.preprocessing as pp
import utils.error_calculator as ec


class SMWrapper(BaseEstimator, RegressorMixin):
    """ A universal sklearn-style wrapper for statsmodels regressors """
    def __init__(self, model_class, fit_intercept=True):
        self.model_class = model_class
        self.fit_intercept = fit_intercept
    def fit(self, X, y):
        if self.fit_intercept:
            X = sm.add_constant(X)
        self.model_ = self.model_class(y, X)
        self.results_ = self.model_.fit()
    def predict(self, X):
        if self.fit_intercept:
            X = sm.add_constant(X)
        return self.results_.predict(X)



sys.setrecursionlimit(1500)

degree = 2
skewness_limit = 1
num_of_cooks = 2
num_of_f_test = 10

# %%
import warnings
warnings.simplefilter("ignore")
import statsmodels.api as sm

# modeling
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# Linear Regression Model - sklearn
from sklearn.model_selection import train_test_split

# %%
df_train_macro = pd.read_csv('../code/data/train_macro3.csv', index_col=0)
df_test_macro = pd.read_csv('../code/data/test_macro3.csv', index_col=0)

# %%
df_train_macro.describe().iloc[[3, 7], :]
# Out:
#       usdrub  full_sq  life_sq  floor   num_room  kitch_sq  state  \
# min  28.8082     10.0      0.0    0.0   0.000000       0.0    1.0
# max  69.4666    729.0    802.0   44.0  21.356604     123.0    4.0
#
#            area_m  preschool_education_centers_raion  \
# min  2.081628e+06                                0.0
# max  2.060718e+08                               13.0
#
#      school_education_centers_raion  ...  market_count_5000   room_size  \
# min                             0.0  ...                0.0    0.000000
# max                            14.0  ...               21.0  224.940665
#
#      avg_price_ID_metro  avg_price_ID_railroad_station_walk  \
# min           3000000.0                        0.000000e+00
# max          56220124.0                        1.984228e+07
#
#      avg_price_ID_big_road1  avg_price_ID_big_road2  \
# min            3.608626e+06            4.516778e+06
# max            1.550000e+07            1.322269e+07
#
#      avg_price_ID_railroad_terminal  avg_price_ID_bus_terminal  \
# min                    6.311649e+06               5.626025e+06
# max                    1.185172e+07               1.004654e+07
#
#      avg_price_sub_area   price_doc
# min        1.000000e+06    395685.0
# max        2.011657e+07  95122496.0
#
# [2 rows x 143 columns]

# %%
# numeric_ivs = df_train_macro._get_numeric_data().columns.drop('price_doc').tolist()
numeric_ivs = df_train_macro._get_numeric_data().columns.tolist()
categorial_ivs = list(df_train_macro.dtypes[df_train_macro.dtypes == object].index)

# %%
df_cat_dummies = pd.get_dummies(df_train_macro[categorial_ivs])

# %%
df_real = df_train_macro[numeric_ivs]

# %%
df_train_macro = pd.concat([df_real, df_cat_dummies], axis=1)
cols = list(df_train_macro.columns.values)
cols.pop(cols.index('price_doc'))
df_train_macro = df_train_macro[cols + ['price_doc']]
df_train_macro.tail(2)

# %%
dfy = df_train_macro.iloc[:, -1]
dfx = df_train_macro.iloc[:, :-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(dfx, dfy, test_size=0.3, random_state=1)
len(X_train), len(X_test), len(y_train), len(y_test)

# %%
# StandardScaler
std_scaler = StandardScaler()
std_scaler.fit(X_train)
X_train_std_scaler = std_scaler.transform(X_train)
std_scaler.fit(X_test)
X_test_std_scaler = std_scaler.transform(X_test)

# %%
# RobustScaler
robust_scaler = RobustScaler()
robust_scaler.fit(X_train)
X_train_robust_scaler = robust_scaler.transform(X_train)
robust_scaler.fit(X_test)
X_train_robust_scaler = robust_scaler.transform(X_test)

# %%
X_train = sm.add_constant(X_train)

# %%
result = sm.OLS(y_train, X_train).fit()
result.summary()

# %%
X_train_std_scaler = sm.add_constant(X_train_std_scaler)
result_std_scaler = sm.OLS(y_train, X_train_std_scaler).fit()
result_std_scaler.summary()

# %%
# X_train_robust_scaler = sm.add_constant(X_train_robust_scaler)
# result_robust_scaler = sm.OLS(y_train, X_train_robust_scaler).fit()
# result_robust_scaler.summary()

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

model = Pipeline([
    ('scaler', StandardScaler()),
    ('regressor', LinearRegression()),
])

# %% [markdown]
# ## Column Names

# %%
new_cols = []
for col in  list(df_train_macro.columns):
    col = col.replace('-', '_').replace('+', '_').replace(':', '_').replace('~', '_').replace('*', '_')
    new_cols.append('_'+col)
df_train_macro.columns = new_cols

new_cols = []
for col in list(df_test_macro.columns):
    col = col.replace('-', '_').replace('+', '_').replace(':', '_').replace('~', '_').replace('*', '_')
    new_cols.append('_'+col)
df_test_macro.columns = new_cols

categorial_ivs = list(set(df_train_macro.columns) - set(df_train_macro._get_numeric_data().columns))
numeric_ivs = df_train_macro._get_numeric_data().columns.drop('_price_doc').tolist()

# %% [markdown]
# ## Log Transformation
# Transform data with skewness greater than 1.

# %%
features_to_log = []
for f in df_train_macro._get_numeric_data().columns:
    skewness = sp.stats.skew(df_train_macro[f])
    if skewness > skewness_limit:
        features_to_log.append(f)

for col in df_train_macro._get_numeric_data().columns:
    if col != '_price_doc':
        min_val_train = min(df_train_macro[col])
        min_val_test  = min(df_test_macro[col])
        min_val = min(min_val_train, min_val_test)
        if min_val <= 0:
            df_train_macro[col] += (np.abs(min_val) + 0.1)
            df_test_macro[col]  += (np.abs(min_val) + 0.1)
    else:
        min_val_train = min(df_train_macro[col])
        if min_val_train <= 0:
            df_train_macro[col] += (np.abs(min_val_train) + 0.1)

# %%
formula = sh.make_statsmodels_ols_formula(numeric_ivs, categorial_ivs, '_price_doc', log_vs=features_to_log, degree=degree, scale=False)
model = sm.OLS.from_formula(formula, data=df_train_macro)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     np.log(_price_doc)   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     580.1
# Date:                Sun, 17 Nov 2019   Prob (F-statistic):               0.00
# Time:                        22:04:40   Log-Likelihood:                -19244.
# No. Observations:               30404   AIC:                         3.857e+04
# Df Residuals:                   30365   BIC:                         3.889e+04
# Df Model:                          38
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  0.0042      0.001      4.802      0.000       0.002       0.006
# C(_product_type)[T.OwnerOccupier]                          0.1471      0.013     11.295      0.000       0.122       0.173
# C(_ecology)[T.good]                                       -0.0059      0.014     -0.432      0.666      -0.033       0.021
# C(_ecology)[T.no data]                                     0.0219      0.009      2.377      0.017       0.004       0.040
# C(_ecology)[T.poor]                                       -0.0020      0.013     -0.157      0.875      -0.027       0.023
# C(_ecology)[T.satisfactory]                               -0.0281      0.014     -1.963      0.050      -0.056   -4.78e-05
# C(_detention_facility_raion)[T.yes]                        0.0163      0.018      0.905      0.365      -0.019       0.051
# C(_incineration_raion)[T.yes]                             -0.0323      0.015     -2.129      0.033      -0.062      -0.003
# C(_thermal_power_plant_raion)[T.yes]                      -0.0242      0.018     -1.310      0.190      -0.060       0.012
# C(_oil_chemistry_raion)[T.yes]                            -0.0027      0.008     -0.336      0.737      -0.018       0.013
# C(_culture_objects_top_25)[T.yes]                         -0.0080      0.019     -0.412      0.681      -0.046       0.030
# C(_big_market_raion)[T.yes]                                0.0373      0.019      1.994      0.046       0.001       0.074
# C(_railroad_terminal_raion)[T.yes]                         0.0434      0.016      2.651      0.008       0.011       0.076
# C(_railroad_1line)[T.yes]                                 -0.0731      0.020     -3.680      0.000      -0.112      -0.034
# C(_radiation_raion)[T.yes]                                -0.0306      0.013     -2.298      0.022      -0.057      -0.004
# C(_water_1line)[T.yes]                                     0.0026      0.013      0.202      0.840      -0.023       0.028
# C(_big_road1_1line)[T.yes]                                -0.0464      0.019     -2.482      0.013      -0.083      -0.010
# C(_nuclear_reactor_raion)[T.yes]                          -0.0153      0.017     -0.895      0.371      -0.049       0.018
# np.log(_usdrub)                                            0.0123      0.001     12.433      0.000       0.010       0.014
# np.log(_full_sq)                                           0.0096      0.004      2.707      0.007       0.003       0.017
# np.log(_life_sq)                                           0.0131      0.008      1.735      0.083      -0.002       0.028
# _floor                                                     0.0076      0.002      4.810      0.000       0.004       0.011
# np.log(_num_room)                                         -0.0334      0.019     -1.739      0.082      -0.071       0.004
# np.log(_kitch_sq)                                         -0.0062      0.003     -1.843      0.065      -0.013       0.000
# _state                                                    -0.1925      0.023     -8.192      0.000      -0.239      -0.146
# np.log(_area_m)                                            0.0217      0.004      6.052      0.000       0.015       0.029
# _preschool_education_centers_raion                         0.0146      0.014      1.024      0.306      -0.013       0.043
# _school_education_centers_raion                            0.0005      0.012      0.039      0.969      -0.023       0.024
# np.log(_school_education_centers_top_20_raion)             0.0213      0.006      3.756      0.000       0.010       0.032
# np.log(_hospital_beds_raion)                              -0.0090      0.017     -0.538      0.591      -0.042       0.024
# np.log(_healthcare_centers_raion)                         -0.0033      0.007     -0.460      0.645      -0.017       0.011
# np.log(_university_top_20_raion)                           0.0185      0.013      1.440      0.150      -0.007       0.044
# np.log(_sport_objects_raion)                              -0.0144      0.008     -1.732      0.083      -0.031       0.002
# np.log(_shopping_centers_raion)                           -0.0025      0.005     -0.492      0.623      -0.012       0.007
# np.log(_office_raion)                                      0.0076      0.005      1.607      0.108      -0.002       0.017
# _0_17_all                                              -1.256e-06   3.73e-06     -0.337      0.736   -8.57e-06    6.05e-06
# np.log(_raion_build_count_with_material_info)             -0.0111      0.011     -0.978      0.328      -0.033       0.011
# np.log(_build_count_brick)                                -0.0026      0.006     -0.450      0.653      -0.014       0.009
# np.log(_build_count_monolith)                             -0.0198      0.005     -4.211      0.000      -0.029      -0.011
# np.log(_raion_build_count_with_builddate_info)            -0.0109      0.011     -0.959      0.338      -0.033       0.011
# np.log(_build_count_before_1920)                          -0.0238      0.011     -2.223      0.026      -0.045      -0.003
# np.log(_metro_min_avto)                                   -0.0127      0.009     -1.416      0.157      -0.030       0.005
# np.log(_kindergarten_km)                                  -0.0225      0.008     -2.796      0.005      -0.038      -0.007
# np.log(_school_km)                                         0.0328      0.009      3.763      0.000       0.016       0.050
# np.log(_park_km)                                          -0.0065      0.008     -0.852      0.394      -0.021       0.008
# np.log(_railroad_station_walk_min)                         0.0174      0.009      2.013      0.044       0.000       0.034
# np.log(_railroad_station_avto_min)                         0.0861      0.015      5.578      0.000       0.056       0.116
# np.log(_public_transport_station_min_walk)                -0.0224      0.006     -3.769      0.000      -0.034      -0.011
# np.log(_ttk_km)                                            0.0661      0.017      3.945      0.000       0.033       0.099
# np.log(_sadovoe_km)                                       -0.0020      0.007     -0.293      0.770      -0.015       0.011
# np.log(_bulvar_ring_km)                                    0.0005      0.010      0.046      0.963      -0.020       0.021
# np.log(_kremlin_km)                                        0.0264      0.011      2.343      0.019       0.004       0.048
# _big_road1_km                                              0.0231      0.014      1.676      0.094      -0.004       0.050
# _big_road2_km                                             -0.0071      0.009     -0.753      0.451      -0.026       0.011
# np.log(_zd_vokzaly_avto_km)                                0.0510      0.021      2.444      0.015       0.010       0.092
# np.log(_bus_terminal_avto_km)                              0.0392      0.019      2.035      0.042       0.001       0.077
# _oil_chemistry_km                                          0.0012      0.004      0.302      0.763      -0.006       0.009
# np.log(_nuclear_reactor_km)                                0.0286      0.012      2.346      0.019       0.005       0.052
# np.log(_radiation_km)                                     -0.0074      0.009     -0.851      0.395      -0.025       0.010
# np.log(_power_transmission_line_km)                        0.0127      0.007      1.705      0.088      -0.002       0.027
# np.log(_thermal_power_plant_km)                            0.0157      0.010      1.541      0.123      -0.004       0.036
# np.log(_ts_km)                                             0.0063      0.013      0.498      0.619      -0.018       0.031
# np.log(_market_shop_km)                                   -0.0186      0.007     -2.576      0.010      -0.033      -0.004
# np.log(_fitness_km)                                       -0.0134      0.013     -1.027      0.304      -0.039       0.012
# np.log(_swim_pool_km)                                      0.0062      0.010      0.649      0.516      -0.012       0.025
# np.log(_ice_rink_km)                                       0.0016      0.016      0.101      0.920      -0.030       0.033
# np.log(_stadium_km)                                        0.0300      0.017      1.763      0.078      -0.003       0.063
# np.log(_basketball_km)                                     0.0219      0.008      2.823      0.005       0.007       0.037
# np.log(_hospice_morgue_km)                                -0.0078      0.007     -1.149      0.251      -0.021       0.006
# np.log(_detention_facility_km)                            -0.0029      0.017     -0.171      0.864      -0.036       0.030
# np.log(_public_healthcare_km)                             -0.0131      0.007     -1.828      0.068      -0.027       0.001
# np.log(_university_km)                                    -0.0143      0.008     -1.845      0.065      -0.029       0.001
# np.log(_workplaces_km)                                    -0.0118      0.008     -1.545      0.122      -0.027       0.003
# np.log(_shopping_centers_km)                               0.0114      0.013      0.887      0.375      -0.014       0.037
# np.log(_office_km)                                        -0.0311      0.019     -1.640      0.101      -0.068       0.006
# np.log(_additional_education_km)                          -0.0273      0.008     -3.512      0.000      -0.043      -0.012
# np.log(_preschool_km)                                     -0.0092      0.009     -1.033      0.302      -0.027       0.008
# np.log(_big_church_km)                                    -0.0210      0.009     -2.386      0.017      -0.038      -0.004
# np.log(_church_synagogue_km)                              -0.0107      0.010     -1.045      0.296      -0.031       0.009
# np.log(_mosque_km)                                         0.0693      0.017      4.144      0.000       0.037       0.102
# np.log(_theater_km)                                       -0.0227      0.016     -1.424      0.154      -0.054       0.009
# np.log(_museum_km)                                        -0.0161      0.015     -1.066      0.286      -0.046       0.014
# np.log(_exhibition_km)                                     0.0118      0.012      0.991      0.322      -0.012       0.035
# np.log(_catering_km)                                      -0.0187      0.013     -1.435      0.151      -0.044       0.007
# np.log(_office_count_500)                                 -0.0151      0.013     -1.133      0.257      -0.041       0.011
# np.log(_office_sqm_500)                                    0.0070      0.007      0.932      0.351      -0.008       0.022
# np.log(_cafe_count_500)                                    0.0095      0.008      1.257      0.209      -0.005       0.024
# np.log(_cafe_count_500_price_1000)                        -0.0074      0.009     -0.838      0.402      -0.025       0.010
# np.log(_cafe_count_500_price_1500)                        -0.0307      0.010     -3.225      0.001      -0.049      -0.012
# np.log(_leisure_count_500)                                 0.0187      0.022      0.859      0.390      -0.024       0.061
# np.log(_office_count_1000)                                -0.0128      0.012     -1.033      0.302      -0.037       0.011
# np.log(_office_sqm_1000)                                   0.0060      0.007      0.918      0.359      -0.007       0.019
# np.log(_cafe_count_1000)                                  -0.0111      0.009     -1.233      0.217      -0.029       0.007
# np.log(_cafe_count_1000_na_price)                          0.0020      0.009      0.220      0.826      -0.015       0.019
# np.log(_cafe_count_1000_price_1000)                        0.0167      0.008      2.139      0.032       0.001       0.032
# np.log(_cafe_count_1000_price_1500)                       -0.0010      0.008     -0.129      0.897      -0.016       0.014
# np.log(_cafe_count_1000_price_high)                        0.0405      0.012      3.308      0.001       0.017       0.064
# np.log(_leisure_count_1000)                                0.0106      0.014      0.749      0.454      -0.017       0.038
# np.log(_sport_count_1000)                                  0.0038      0.005      0.758      0.448      -0.006       0.014
# np.log(_office_count_1500)                                 0.0154      0.016      0.963      0.335      -0.016       0.047
# np.log(_office_sqm_1500)                                  -0.0124      0.009     -1.404      0.160      -0.030       0.005
# np.log(_trc_count_1500)                                    0.0015      0.006      0.244      0.807      -0.010       0.013
# np.log(_cafe_count_1500)                                   0.0373      0.013      2.801      0.005       0.011       0.063
# _cafe_sum_1500_min_price_avg                              -0.0138      0.010     -1.354      0.176      -0.034       0.006
# _cafe_sum_1500_max_price_avg                              -0.0138      0.011     -1.240      0.215      -0.036       0.008
# _cafe_avg_price_1500                                       0.0273      0.021      1.273      0.203      -0.015       0.069
# np.log(_cafe_count_1500_na_price)                         -0.0107      0.009     -1.224      0.221      -0.028       0.006
# np.log(_cafe_count_1500_price_500)                        -0.0227      0.010     -2.347      0.019      -0.042      -0.004
# np.log(_cafe_count_1500_price_1000)                       -0.0530      0.013     -3.946      0.000      -0.079      -0.027
# np.log(_cafe_count_1500_price_1500)                        0.0008      0.012      0.074      0.941      -0.022       0.023
# np.log(_cafe_count_1500_price_2500)                       -0.0037      0.009     -0.430      0.667      -0.021       0.013
# np.log(_cafe_count_1500_price_high)                        0.0263      0.017      1.550      0.121      -0.007       0.060
# np.log(_mosque_count_1500)                                 0.0055      0.002      3.004      0.003       0.002       0.009
# np.log(_leisure_count_1500)                               -0.0081      0.010     -0.791      0.429      -0.028       0.012
# np.log(_sport_count_1500)                                 -0.0059      0.008     -0.783      0.434      -0.021       0.009
# _green_part_2000                                          -0.0006      0.002     -0.400      0.689      -0.004       0.002
# np.log(_office_count_2000)                                -0.0685      0.020     -3.422      0.001      -0.108      -0.029
# np.log(_office_sqm_2000)                                   0.0205      0.011      1.846      0.065      -0.001       0.042
# np.log(_trc_count_2000)                                    0.0185      0.018      1.017      0.309      -0.017       0.054
# np.log(_trc_sqm_2000)                                     -0.0164      0.010     -1.718      0.086      -0.035       0.002
# np.log(_cafe_count_2000)                                   0.0253      0.010      2.499      0.012       0.005       0.045
# np.log(_cafe_sum_2000_max_price_avg)                       0.0139      0.002      6.232      0.000       0.010       0.018
# np.log(_cafe_count_2000_na_price)                         -0.0055      0.008     -0.736      0.462      -0.020       0.009
# np.log(_cafe_count_2000_price_500)                        -0.0176      0.009     -1.986      0.047      -0.035      -0.000
# np.log(_cafe_count_2000_price_1000)                        0.0126      0.009      1.383      0.167      -0.005       0.031
# np.log(_cafe_count_2000_price_1500)                       -0.0243      0.009     -2.821      0.005      -0.041      -0.007
# np.log(_cafe_count_2000_price_2500)                       -0.0264      0.008     -3.262      0.001      -0.042      -0.011
# np.log(_cafe_count_2000_price_high)                       -0.0372      0.018     -2.084      0.037      -0.072      -0.002
# np.log(_mosque_count_2000)                                 0.0011      0.002      0.719      0.472      -0.002       0.004
# np.log(_sport_count_2000)                                  0.0316      0.009      3.560      0.000       0.014       0.049
# np.log(_market_count_2000)                                -0.0007      0.007     -0.097      0.923      -0.015       0.013
# _green_part_3000                                           0.0042      0.002      1.804      0.071      -0.000       0.009
# np.log(_office_count_3000)                                -0.0177      0.014     -1.223      0.221      -0.046       0.011
# np.log(_office_sqm_3000)                                   0.0140      0.009      1.640      0.101      -0.003       0.031
# np.log(_trc_count_3000)                                    0.0211      0.007      3.073      0.002       0.008       0.035
# np.log(_trc_sqm_3000)                                      0.0061      0.007      0.828      0.407      -0.008       0.021
# np.log(_big_church_count_3000)                            -0.0098      0.008     -1.285      0.199      -0.025       0.005
# np.log(_church_count_3000)                                -0.0386      0.015     -2.591      0.010      -0.068      -0.009
# np.log(_leisure_count_3000)                                0.0018      0.007      0.263      0.793      -0.012       0.016
# np.log(_sport_count_3000)                                  0.0007      0.010      0.071      0.944      -0.019       0.020
# _market_count_3000                                         0.0081      0.009      0.917      0.359      -0.009       0.025
# _green_part_5000                                          -0.0042      0.004     -1.198      0.231      -0.011       0.003
# np.log(_office_count_5000)                                -0.0666      0.019     -3.575      0.000      -0.103      -0.030
# np.log(_office_sqm_5000)                                   0.0213      0.011      1.972      0.049       0.000       0.042
# _trc_count_5000                                            0.0029      0.002      1.367      0.172      -0.001       0.007
# _trc_sqm_5000                                          -2.475e-08   3.54e-08     -0.699      0.485   -9.41e-08    4.47e-08
# np.log(_big_church_count_5000)                             0.0306      0.011      2.731      0.006       0.009       0.053
# np.log(_church_count_5000)                                -0.0331      0.019     -1.696      0.090      -0.071       0.005
# np.log(_mosque_count_5000)                                 0.0523      0.020      2.602      0.009       0.013       0.092
# np.log(_leisure_count_5000)                                0.0121      0.007      1.647      0.100      -0.002       0.026
# np.log(_sport_count_5000)                                 -0.0007      0.012     -0.062      0.950      -0.023       0.022
# _market_count_5000                                        -0.0194      0.007     -2.834      0.005      -0.033      -0.006
# np.log(_room_size)                                        -0.0026      0.007     -0.371      0.711      -0.016       0.011
# np.log(_avg_price_ID_metro)                                0.0302      0.005      6.088      0.000       0.021       0.040
# np.log(_avg_price_ID_railroad_station_walk)               -0.0495      0.022     -2.288      0.022      -0.092      -0.007
# np.log(_avg_price_ID_big_road1)                            0.0313      0.005      6.004      0.000       0.021       0.041
# _avg_price_ID_big_road2                                 4.089e-08   1.96e-08      2.086      0.037    2.47e-09    7.93e-08
# np.log(_avg_price_ID_railroad_terminal)                    0.0309      0.005      5.903      0.000       0.021       0.041
# _avg_price_ID_bus_terminal                              2.452e-07    6.6e-08      3.717      0.000    1.16e-07    3.74e-07
# np.log(_avg_price_sub_area)                                0.0299      0.005      5.847      0.000       0.020       0.040
# I(np.log(_usdrub) ** 2)                                    0.0306      0.002     17.412      0.000       0.027       0.034
# I(np.log(_full_sq) ** 2)                                   0.1014      0.003     40.475      0.000       0.097       0.106
# I(np.log(_life_sq) ** 2)                                   0.0021      0.003      0.593      0.553      -0.005       0.009
# I(_floor ** 2)                                            -0.0001    7.1e-05     -1.933      0.053      -0.000    1.91e-06
# I(np.log(_num_room) ** 2)                                 -0.0180      0.013     -1.413      0.158      -0.043       0.007
# I(np.log(_kitch_sq) ** 2)                                  0.0072      0.002      4.192      0.000       0.004       0.011
# I(_state ** 2)                                             0.0537      0.005     10.694      0.000       0.044       0.064
# I(np.log(_area_m) ** 2)                                   -0.0002      0.000     -0.407      0.684      -0.001       0.001
# I(_preschool_education_centers_raion ** 2)                -0.0019      0.001     -1.385      0.166      -0.005       0.001
# I(_school_education_centers_raion ** 2)                   -0.0003      0.001     -0.280      0.779      -0.002       0.002
# I(np.log(_school_education_centers_top_20_raion) ** 2)     0.0025      0.004      0.663      0.507      -0.005       0.010
# I(np.log(_hospital_beds_raion) ** 2)                       0.0022      0.001      1.510      0.131      -0.001       0.005
# I(np.log(_healthcare_centers_raion) ** 2)                 -0.0047      0.005     -1.002      0.316      -0.014       0.004
# I(np.log(_university_top_20_raion) ** 2)                   0.0199      0.007      3.002      0.003       0.007       0.033
# I(np.log(_sport_objects_raion) ** 2)                       0.0032      0.003      1.082      0.279      -0.003       0.009
# I(np.log(_shopping_centers_raion) ** 2)                    0.0052      0.003      1.649      0.099      -0.001       0.011
# I(np.log(_office_raion) ** 2)                             -0.0023      0.002     -0.984      0.325      -0.007       0.002
# I(_0_17_all ** 2)                                       7.963e-11   9.43e-11      0.845      0.398   -1.05e-10    2.64e-10
# I(np.log(_raion_build_count_with_material_info) ** 2)      0.0036      0.002      1.778      0.075      -0.000       0.008
# I(np.log(_build_count_brick) ** 2)                        -0.0011      0.001     -0.842      0.400      -0.004       0.001
# I(np.log(_build_count_monolith) ** 2)                     -0.0035      0.002     -1.825      0.068      -0.007       0.000
# I(np.log(_raion_build_count_with_builddate_info) ** 2)     0.0062      0.002      2.890      0.004       0.002       0.010
# I(np.log(_build_count_before_1920) ** 2)                  -0.0001      0.002     -0.056      0.955      -0.005       0.005
# I(np.log(_metro_min_avto) ** 2)                           -0.0185      0.005     -3.717      0.000      -0.028      -0.009
# I(np.log(_kindergarten_km) ** 2)                          -0.0031      0.002     -1.775      0.076      -0.007       0.000
# I(np.log(_school_km) ** 2)                                -0.0252      0.010     -2.412      0.016      -0.046      -0.005
# I(np.log(_park_km) ** 2)                                  -0.0042      0.004     -1.024      0.306      -0.012       0.004
# I(np.log(_railroad_station_walk_min) ** 2)                -0.0145      0.003     -5.513      0.000      -0.020      -0.009
# I(np.log(_railroad_station_avto_min) ** 2)                -0.0122      0.006     -1.915      0.055      -0.025       0.000
# I(np.log(_public_transport_station_min_walk) ** 2)         0.0097      0.003      2.998      0.003       0.003       0.016
# I(np.log(_ttk_km) ** 2)                                    0.0262      0.007      3.741      0.000       0.012       0.040
# I(np.log(_sadovoe_km) ** 2)                                0.0010      0.004      0.220      0.826      -0.008       0.010
# I(np.log(_bulvar_ring_km) ** 2)                           -0.0033      0.006     -0.590      0.555      -0.014       0.008
# I(np.log(_kremlin_km) ** 2)                               -0.0165      0.010     -1.602      0.109      -0.037       0.004
# I(_big_road1_km ** 2)                                     -0.0050      0.003     -1.676      0.094      -0.011       0.001
# I(_big_road2_km ** 2)                                      0.0025      0.001      2.349      0.019       0.000       0.005
# I(np.log(_zd_vokzaly_avto_km) ** 2)                       -0.0271      0.009     -3.020      0.003      -0.045      -0.010
# I(np.log(_bus_terminal_avto_km) ** 2)                     -0.0050      0.007     -0.736      0.462      -0.018       0.008
# I(_oil_chemistry_km ** 2)                                 -0.0003   8.56e-05     -2.935      0.003      -0.000   -8.35e-05
# I(np.log(_nuclear_reactor_km) ** 2)                       -0.0039      0.007     -0.567      0.571      -0.017       0.010
# I(np.log(_radiation_km) ** 2)                              0.0037      0.005      0.793      0.428      -0.005       0.013
# I(np.log(_power_transmission_line_km) ** 2)                0.0086      0.005      1.833      0.067      -0.001       0.018
# I(np.log(_thermal_power_plant_km) ** 2)                   -0.0274      0.007     -3.811      0.000      -0.041      -0.013
# I(np.log(_ts_km) ** 2)                                    -0.0082      0.007     -1.107      0.268      -0.023       0.006
# I(np.log(_market_shop_km) ** 2)                            0.0073      0.005      1.566      0.117      -0.002       0.016
# I(np.log(_fitness_km) ** 2)                                0.0086      0.008      1.143      0.253      -0.006       0.023
# I(np.log(_swim_pool_km) ** 2)                              0.0142      0.007      2.086      0.037       0.001       0.028
# I(np.log(_ice_rink_km) ** 2)                               0.0092      0.007      1.254      0.210      -0.005       0.024
# I(np.log(_stadium_km) ** 2)                               -0.0154      0.007     -2.242      0.025      -0.029      -0.002
# I(np.log(_basketball_km) ** 2)                             0.0183      0.005      3.646      0.000       0.008       0.028
# I(np.log(_hospice_morgue_km) ** 2)                        -0.0131      0.004     -3.133      0.002      -0.021      -0.005
# I(np.log(_detention_facility_km) ** 2)                     0.0136      0.006      2.238      0.025       0.002       0.025
# I(np.log(_public_healthcare_km) ** 2)                      0.0132      0.006      2.131      0.033       0.001       0.025
# I(np.log(_university_km) ** 2)                             0.0029      0.003      0.834      0.404      -0.004       0.010
# I(np.log(_workplaces_km) ** 2)                            -0.0165      0.007     -2.500      0.012      -0.029      -0.004
# I(np.log(_shopping_centers_km) ** 2)                       0.0056      0.008      0.676      0.499      -0.011       0.022
# I(np.log(_office_km) ** 2)                                -0.0260      0.008     -3.292      0.001      -0.041      -0.010
# I(np.log(_additional_education_km) ** 2)                  -0.0005      0.006     -0.079      0.937      -0.013       0.012
# I(np.log(_preschool_km) ** 2)                              0.0492      0.011      4.618      0.000       0.028       0.070
# I(np.log(_big_church_km) ** 2)                            -0.0038      0.004     -0.916      0.360      -0.012       0.004
# I(np.log(_church_synagogue_km) ** 2)                      -0.0149      0.008     -1.898      0.058      -0.030       0.000
# I(np.log(_mosque_km) ** 2)                                -0.0021      0.006     -0.376      0.707      -0.013       0.009
# I(np.log(_theater_km) ** 2)                                0.0031      0.006      0.522      0.601      -0.009       0.015
# I(np.log(_museum_km) ** 2)                                 0.0012      0.006      0.185      0.853      -0.011       0.014
# I(np.log(_exhibition_km) ** 2)                             0.0183      0.006      3.150      0.002       0.007       0.030
# I(np.log(_catering_km) ** 2)                              -0.0031      0.002     -1.308      0.191      -0.008       0.002
# I(np.log(_office_count_500) ** 2)                          0.0009      0.006      0.157      0.875      -0.011       0.013
# I(np.log(_office_sqm_500) ** 2)                           -0.0005      0.001     -0.719      0.472      -0.002       0.001
# I(np.log(_cafe_count_500) ** 2)                            0.0053      0.003      1.761      0.078      -0.001       0.011
# I(np.log(_cafe_count_500_price_1000) ** 2)                -0.0022      0.004     -0.580      0.562      -0.010       0.005
# I(np.log(_cafe_count_500_price_1500) ** 2)                -0.0110      0.004     -2.578      0.010      -0.019      -0.003
# I(np.log(_leisure_count_500) ** 2)                         0.0151      0.010      1.450      0.147      -0.005       0.036
# I(np.log(_office_count_1000) ** 2)                         0.0093      0.005      1.883      0.060      -0.000       0.019
# I(np.log(_office_sqm_1000) ** 2)                       -5.224e-05      0.001     -0.095      0.924      -0.001       0.001
# I(np.log(_cafe_count_1000) ** 2)                          -0.0059      0.004     -1.633      0.103      -0.013       0.001
# I(np.log(_cafe_count_1000_na_price) ** 2)                 -0.0056      0.004     -1.371      0.170      -0.014       0.002
# I(np.log(_cafe_count_1000_price_1000) ** 2)                0.0070      0.003      2.327      0.020       0.001       0.013
# I(np.log(_cafe_count_1000_price_1500) ** 2)               -0.0001      0.003     -0.037      0.970      -0.006       0.006
# I(np.log(_cafe_count_1000_price_high) ** 2)                0.0205      0.008      2.551      0.011       0.005       0.036
# I(np.log(_leisure_count_1000) ** 2)                        0.0037      0.007      0.550      0.583      -0.010       0.017
# I(np.log(_sport_count_1000) ** 2)                         -0.0002      0.002     -0.101      0.920      -0.005       0.004
# I(np.log(_office_count_1500) ** 2)                        -0.0131      0.006     -2.028      0.043      -0.026      -0.000
# I(np.log(_office_sqm_1500) ** 2)                           0.0003      0.001      0.456      0.649      -0.001       0.002
# I(np.log(_trc_count_1500) ** 2)                            0.0003      0.003      0.092      0.927      -0.005       0.006
# I(np.log(_cafe_count_1500) ** 2)                           0.0144      0.006      2.333      0.020       0.002       0.027
# I(_cafe_sum_1500_min_price_avg ** 2)                    6.484e-06   5.23e-06      1.239      0.215   -3.77e-06    1.67e-05
# I(_cafe_sum_1500_max_price_avg ** 2)                    4.056e-06   3.56e-06      1.140      0.254   -2.92e-06     1.1e-05
# I(_cafe_avg_price_1500 ** 2)                           -9.896e-06   8.47e-06     -1.169      0.242   -2.65e-05     6.7e-06
# I(np.log(_cafe_count_1500_na_price) ** 2)                 -0.0029      0.004     -0.745      0.456      -0.010       0.005
# I(np.log(_cafe_count_1500_price_500) ** 2)                -0.0012      0.003     -0.351      0.725      -0.008       0.005
# I(np.log(_cafe_count_1500_price_1000) ** 2)               -0.0052      0.004     -1.342      0.180      -0.013       0.002
# I(np.log(_cafe_count_1500_price_1500) ** 2)               -0.0101      0.004     -2.877      0.004      -0.017      -0.003
# I(np.log(_cafe_count_1500_price_2500) ** 2)                0.0003      0.004      0.074      0.941      -0.007       0.007
# I(np.log(_cafe_count_1500_price_high) ** 2)               -0.0103      0.009     -1.201      0.230      -0.027       0.007
# I(np.log(_mosque_count_1500) ** 2)                        -0.0113      0.004     -2.799      0.005      -0.019      -0.003
# I(np.log(_leisure_count_1500) ** 2)                       -0.0016      0.005     -0.333      0.739      -0.011       0.008
# I(np.log(_sport_count_1500) ** 2)                          0.0054      0.003      1.851      0.064      -0.000       0.011
# I(_green_part_2000 ** 2)                               -2.431e-05   2.62e-05     -0.929      0.353   -7.56e-05     2.7e-05
# I(np.log(_office_count_2000) ** 2)                         0.0168      0.007      2.378      0.017       0.003       0.031
# I(np.log(_office_sqm_2000) ** 2)                          -0.0002      0.001     -0.328      0.743      -0.002       0.001
# I(np.log(_trc_count_2000) ** 2)                           -0.0037      0.006     -0.620      0.535      -0.016       0.008
# I(np.log(_trc_sqm_2000) ** 2)                              0.0007      0.001      1.323      0.186      -0.000       0.002
# I(np.log(_cafe_count_2000) ** 2)                           0.0108      0.005      2.280      0.023       0.002       0.020
# I(np.log(_cafe_sum_2000_max_price_avg) ** 2)               0.0023      0.002      1.084      0.278      -0.002       0.006
# I(np.log(_cafe_count_2000_na_price) ** 2)                 -0.0042      0.004     -1.166      0.244      -0.011       0.003
# I(np.log(_cafe_count_2000_price_500) ** 2)                -0.0076      0.003     -2.414      0.016      -0.014      -0.001
# I(np.log(_cafe_count_2000_price_1000) ** 2)                0.0023      0.004      0.611      0.541      -0.005       0.010
# I(np.log(_cafe_count_2000_price_1500) ** 2)                0.0044      0.004      1.184      0.236      -0.003       0.012
# I(np.log(_cafe_count_2000_price_2500) ** 2)               -0.0140      0.003     -4.008      0.000      -0.021      -0.007
# I(np.log(_cafe_count_2000_price_high) ** 2)               -0.0076      0.009     -0.882      0.378      -0.025       0.009
# I(np.log(_mosque_count_2000) ** 2)                        -0.0016      0.003     -0.478      0.633      -0.008       0.005
# I(np.log(_sport_count_2000) ** 2)                         -0.0042      0.003     -1.334      0.182      -0.010       0.002
# I(np.log(_market_count_2000) ** 2)                        -0.0016      0.004     -0.447      0.655      -0.009       0.005
# I(_green_part_3000 ** 2)                                -3.49e-05   3.98e-05     -0.877      0.380      -0.000    4.31e-05
# I(np.log(_office_count_3000) ** 2)                         0.0005      0.005      0.104      0.917      -0.009       0.010
# I(np.log(_office_sqm_3000) ** 2)                          -0.0013      0.001     -1.966      0.049      -0.003   -3.98e-06
# I(np.log(_trc_count_3000) ** 2)                           -0.0099      0.004     -2.239      0.025      -0.018      -0.001
# I(np.log(_trc_sqm_3000) ** 2)                             -0.0007      0.001     -1.147      0.251      -0.002       0.000
# I(np.log(_big_church_count_3000) ** 2)                    -0.0106      0.003     -3.086      0.002      -0.017      -0.004
# I(np.log(_church_count_3000) ** 2)                         0.0084      0.005      1.762      0.078      -0.001       0.018
# I(np.log(_leisure_count_3000) ** 2)                        0.0042      0.003      1.266      0.206      -0.002       0.011
# I(np.log(_sport_count_3000) ** 2)                          0.0048      0.003      1.455      0.146      -0.002       0.011
# I(_market_count_3000 ** 2)                                -0.0007      0.001     -0.675      0.500      -0.003       0.001
# I(_green_part_5000 ** 2)                                7.688e-05   6.08e-05      1.265      0.206   -4.22e-05       0.000
# I(np.log(_office_count_5000) ** 2)                         0.0126      0.005      2.654      0.008       0.003       0.022
# I(np.log(_office_sqm_5000) ** 2)                          -0.0005      0.001     -0.556      0.578      -0.002       0.001
# I(_trc_count_5000 ** 2)                                -2.677e-05   1.86e-05     -1.439      0.150   -6.32e-05    9.69e-06
# I(_trc_sqm_5000 ** 2)                                   2.031e-15   7.87e-15      0.258      0.796   -1.34e-14    1.74e-14
# I(np.log(_big_church_count_5000) ** 2)                     0.0006      0.004      0.161      0.872      -0.007       0.008
# I(np.log(_church_count_5000) ** 2)                         0.0156      0.006      2.697      0.007       0.004       0.027
# I(np.log(_mosque_count_5000) ** 2)                         0.0208      0.010      2.168      0.030       0.002       0.040
# I(np.log(_leisure_count_5000) ** 2)                        0.0011      0.003      0.367      0.714      -0.005       0.007
# I(np.log(_sport_count_5000) ** 2)                         -0.0100      0.004     -2.471      0.013      -0.018      -0.002
# I(_market_count_5000 ** 2)                                 0.0012      0.000      3.531      0.000       0.001       0.002
# I(np.log(_room_size) ** 2)                                -0.0084      0.003     -2.393      0.017      -0.015      -0.002
# I(np.log(_avg_price_ID_metro) ** 2)                        0.0106      0.001     12.546      0.000       0.009       0.012
# I(np.log(_avg_price_ID_railroad_station_walk) ** 2)        0.0046      0.002      3.013      0.003       0.002       0.008
# I(np.log(_avg_price_ID_big_road1) ** 2)                    0.0063      0.001      5.486      0.000       0.004       0.009
# I(_avg_price_ID_big_road2 ** 2)                        -2.062e-15   1.12e-15     -1.844      0.065   -4.25e-15    1.29e-16
# I(np.log(_avg_price_ID_railroad_terminal) ** 2)            0.0130      0.002      6.848      0.000       0.009       0.017
# I(_avg_price_ID_bus_terminal ** 2)                     -1.501e-14   4.23e-15     -3.545      0.000   -2.33e-14   -6.71e-15
# I(np.log(_avg_price_sub_area) ** 2)                        0.0075      0.001      6.220      0.000       0.005       0.010
# ==============================================================================
# Omnibus:                    15579.967   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            92254.635
# Skew:                          -2.488   Prob(JB):                         0.00
# Kurtosis:                       9.933   Cond. No.                     1.75e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.75e+17. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Condition Number
# Large condition number occurs when the scale of data changes significantly due to the unit difference. Scaling can decrease condition number. Multicollinearity can also cause large condition number. We can handle this by reducing dimensionality with variance inflation factor.

# %% [markdown]
# ## Standard Scaling
# Standalize variables by removing the mean and scaling to unit variance.

# %%
formula = sh.make_statsmodels_ols_formula(numeric_ivs, categorial_ivs, '_price_doc', log_vs=features_to_log, degree=degree, scale=True)
model = sm.OLS.from_formula(formula, data=df_train_macro)
result = model.fit()
result.summary()

# %% [markdown]
# Scaling did not significantly decrease the condition number.

# %% [markdown]
# # 2. Dimensionality Reduction
# ## ANOVA

# %%
anova = sm.stats.anova_lm(result, typ=2)
anova

# %% [markdown]
# We can remove features with p-value equal or greater than 0.05 since they have very small influences on the dependent variable

# %% [markdown]
# ## F-test and Feature Influence

# %%
result, sms_vars, formula = fs.by_f_test(df_train_macro, formula, repeat=num_of_f_test)
result.summary()

# %% [markdown]
# # 3. Outlier
# ## Cook's Distance
# - Find data with large leverage and residual by calculating Cook's distance.

# %%
df_train_macro_with_outliers = df_train_macro.copy(deep=True)
df_train_macro, model, result = pp.remove_outliers(df_train_macro, formula, repeat=3)
result.summary()

# %% [markdown]
# # 4. Regularization
# ## Lasso
# Find variables with zero coefficient when Lasso regularization is applied.

# %%
result_lasso = model.fit_regularized(alpha=0.001, L1_wt=1)

# %% [markdown]
# Let's remove features with zero coefficient to reduce dimensionality.

# %%
sms_vars = []
for idx, coef in enumerate(result_lasso.params):
    if coef ==0:
        continue
    feature = result_lasso.params.index[idx]
    if feature == 'Intercept':
        continue
    startDelPos = feature.find('[')
    endDelPos = feature.find(']')
    feature = feature.replace(feature[startDelPos:endDelPos+1], '')
    sms_vars.append(feature)

# %%
formula = 'np.log(_price_doc) ~ ' + " + ".join(sms_vars)
model =sm.OLS.from_formula(formula, data=df_train_macro)
result = model.fit()
result.summary()

# %% [markdown]
# # 5. Diagnosis of Regression
# ## Residual Normality Test

# %%
# outlier remove result 
sp.stats.probplot(result.resid, plot=plt)
plt.show()

# %%
test = sms.omni_normtest(result.resid)
for xi in zip(['Chi^2', 'P-value'], test):
    print("%-12s: %6.3f" % xi)

# %% [markdown]
# # Partial Regression Plot
# Let's visualize the influence of a single independent variable.

# %%
fig = plt.figure(figsize=(10,70))
sm.graphics.plot_partregress_grid(result, fig=fig)
fig.suptitle("")
plt.show()

# %% [markdown]
# # 6. Cross Validation

# %%
dm = dmatrix(" + ".join(sms_vars) + ' + np.log(_price_doc)', df_train_macro_with_outliers, return_type="dataframe")
X = dm[dm.columns.drop(['np.log(_price_doc)'])]
y = dm['np.log(_price_doc)']
cv = cv = KFold(n_splits=1000, shuffle=True, random_state=0)
r2s = cross_val_score(SMWrapper(sm.OLS), X, y, scoring='r2', cv=cv)
r2s.mean()

# %%
plt.hist(r2s, bins=100)

# %%
y_pred = np.exp(result.predict(df_test_macro))
y_pred = y_pred.to_frame('price_doc')
y_pred.to_csv('./data/stats_models_{}.csv'.format(datetime.datetime.now().strftime('%Y_%m_%d_%H_%M_%S')), header=True, index=True)

# %% [markdown]
# ## Score

# %% [markdown]
# 0.39773
